# %%
#import logging
#logging.getLogger().setLevel(logging.ERROR)

import warnings

warnings.filterwarnings("ignore", category=UserWarning)

import numpy as np
from tqdm import tqdm
import torch
import torch.nn as nn
import torch.utils.data
import itertools
from torch.utils.data import Dataset
import torchani
import matplotlib.pyplot as plt
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader as GraphDataLoader
from torch_geometric.utils import scatter
from rdkit import RDLogger
RDLogger.logger().setLevel(RDLogger.CRITICAL)

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import rdDepictor
from rdkit.Chem.rdmolops import GetAdjacencyMatrix

from torch_geometric.utils.convert import from_scipy_sparse_matrix

IPythonConsole.ipython_useSVG = True  # Enable SVG rendering
rdDepictor.SetPreferCoordGen(True)  # Ensure molecule coordinates are generated

# %%
"""
Module for generating rdkit molobj/smiles/molecular graph from free atoms

Implementation by Jan H. Jensen, based on the paper

    Yeonjoon Kim and Woo Youn Kim
    "Universal Structure Conversion Method for Organic Molecules: From Atomic Connectivity
    to Three-Dimensional Geometry"
    Bull. Korean Chem. Soc. 2015, Vol. 36, 1769-1777
    DOI: 10.1002/bkcs.10334

"""

import copy
import itertools

from rdkit.Chem import rdmolops
from rdkit.Chem import rdchem
try:
    from rdkit.Chem import rdEHTTools #requires RDKit 2019.9.1 or later
except ImportError:
    rdEHTTools = None
    
from collections import defaultdict

import numpy as np
import networkx as nx

from rdkit import Chem
from rdkit.Chem import AllChem, rdmolops
import sys

global __ATOM_LIST__
__ATOM_LIST__ = \
    ['h',  'he',
     'li', 'be', 'b',  'c',  'n',  'o',  'f',  'ne',
     'na', 'mg', 'al', 'si', 'p',  's',  'cl', 'ar',
     'k',  'ca', 'sc', 'ti', 'v ', 'cr', 'mn', 'fe', 'co', 'ni', 'cu',
     'zn', 'ga', 'ge', 'as', 'se', 'br', 'kr',
     'rb', 'sr', 'y',  'zr', 'nb', 'mo', 'tc', 'ru', 'rh', 'pd', 'ag',
     'cd', 'in', 'sn', 'sb', 'te', 'i',  'xe',
     'cs', 'ba', 'la', 'ce', 'pr', 'nd', 'pm', 'sm', 'eu', 'gd', 'tb', 'dy',
     'ho', 'er', 'tm', 'yb', 'lu', 'hf', 'ta', 'w',  're', 'os', 'ir', 'pt',
     'au', 'hg', 'tl', 'pb', 'bi', 'po', 'at', 'rn',
     'fr', 'ra', 'ac', 'th', 'pa', 'u',  'np', 'pu']


global atomic_valence
global atomic_valence_electrons

atomic_valence = defaultdict(list)
atomic_valence[1] = [1]
atomic_valence[5] = [3,4]
atomic_valence[6] = [4]
atomic_valence[7] = [3,4]
atomic_valence[8] = [2,1,3]
atomic_valence[9] = [1]
atomic_valence[14] = [4]
atomic_valence[15] = [5,3] #[5,4,3]
atomic_valence[16] = [6,3,2] #[6,4,2]
atomic_valence[17] = [1]
atomic_valence[32] = [4]
atomic_valence[35] = [1]
atomic_valence[53] = [1]

atomic_valence_electrons = {}
atomic_valence_electrons[1] = 1
atomic_valence_electrons[5] = 3
atomic_valence_electrons[6] = 4
atomic_valence_electrons[7] = 5
atomic_valence_electrons[8] = 6
atomic_valence_electrons[9] = 7
atomic_valence_electrons[14] = 4
atomic_valence_electrons[15] = 5
atomic_valence_electrons[16] = 6
atomic_valence_electrons[17] = 7
atomic_valence_electrons[32] = 4
atomic_valence_electrons[35] = 7
atomic_valence_electrons[53] = 7


def str_atom(atom):
    """
    convert integer atom to string atom
    """
    global __ATOM_LIST__
    atom = __ATOM_LIST__[atom - 1]
    return atom


def int_atom(atom):
    """
    convert str atom to integer atom
    """
    global __ATOM_LIST__
    #print(atom)
    atom = atom.lower()
    return __ATOM_LIST__.index(atom) + 1


def get_UA(maxValence_list, valence_list):
    """
    """
    UA = []
    DU = []
    for i, (maxValence, valence) in enumerate(zip(maxValence_list, valence_list)):
        if not maxValence - valence > 0:
            continue
        UA.append(i)
        DU.append(maxValence - valence)
    return UA, DU


def get_BO(AC, UA, DU, valences, UA_pairs, use_graph=True):
    """
    """
    BO = AC.copy()
    DU_save = []

    while DU_save != DU:
        for i, j in UA_pairs:
            BO[i, j] += 1
            BO[j, i] += 1

        BO_valence = list(BO.sum(axis=1))
        DU_save = copy.copy(DU)
        UA, DU = get_UA(valences, BO_valence)
        UA_pairs = get_UA_pairs(UA, AC, use_graph=use_graph)[0]

    return BO


def valences_not_too_large(BO, valences):
    """
    """
    number_of_bonds_list = BO.sum(axis=1)
    for valence, number_of_bonds in zip(valences, number_of_bonds_list):
        if number_of_bonds > valence:
            return False

    return True

def charge_is_OK(BO, AC, charge, DU, atomic_valence_electrons, atoms, valences,
                 allow_charged_fragments=True):
    # total charge
    Q = 0
    # charge fragment list
    q_list = []

    if allow_charged_fragments:

        BO_valences = list(BO.sum(axis=1))
        for i, atom in enumerate(atoms):
            q = get_atomic_charge(atom, atomic_valence_electrons[atom], BO_valences[i])
            Q += q
            if atom == 6:
                number_of_single_bonds_to_C = list(BO[i, :]).count(1)
                if number_of_single_bonds_to_C == 2 and BO_valences[i] == 2:
                    Q += 1
                    q = 2
                if number_of_single_bonds_to_C == 3 and Q + 1 < charge:
                    Q += 2
                    q = 1

            if q != 0:
                q_list.append(q)

    return (charge == Q)

def BO_is_OK(BO, AC, charge, DU, atomic_valence_electrons, atoms, valences,
    allow_charged_fragments=True):
    """
    Sanity of bond-orders

    args:
        BO -
        AC -
        charge -
        DU - 


    optional
        allow_charges_fragments - 


    returns:
        boolean - true of molecule is OK, false if not
    """
    if not valences_not_too_large(BO, valences):
        return False

    check_sum = (BO - AC).sum() == sum(DU)
    check_charge = charge_is_OK(BO, AC, charge, DU, atomic_valence_electrons, atoms, valences,
                                allow_charged_fragments)

    if check_charge and check_sum: 
        return True

    return False


def get_atomic_charge(atom, atomic_valence_electrons, BO_valence):
    """
    """
    if atom == 1:
        charge = 1 - BO_valence
    elif atom == 5:
        charge = 3 - BO_valence
    elif atom == 15 and BO_valence == 5:
        charge = 0
    elif atom == 16 and BO_valence == 6:
        charge = 0
    else:
        charge = atomic_valence_electrons - 8 + BO_valence

    return charge


def clean_charges(mol):
    """
    This hack should not be needed anymore, but is kept just in case

    """
    Chem.SanitizeMol(mol)
    #rxn_smarts = ['[N+:1]=[*:2]-[C-:3]>>[N+0:1]-[*:2]=[C-0:3]',
    #              '[N+:1]=[*:2]-[O-:3]>>[N+0:1]-[*:2]=[O-0:3]',
    #              '[N+:1]=[*:2]-[*:3]=[*:4]-[O-:5]>>[N+0:1]-[*:2]=[*:3]-[*:4]=[O-0:5]',
    #              '[#8:1]=[#6:2]([!-:6])[*:3]=[*:4][#6-:5]>>[*-:1][*:2]([*:6])=[*:3][*:4]=[*+0:5]',
    #              '[O:1]=[c:2][c-:3]>>[*-:1][*:2][*+0:3]',
    #              '[O:1]=[C:2][C-:3]>>[*-:1][*:2]=[*+0:3]']

    rxn_smarts = ['[#6,#7:1]1=[#6,#7:2][#6,#7:3]=[#6,#7:4][CX3-,NX3-:5][#6,#7:6]1=[#6,#7:7]>>'
                  '[#6,#7:1]1=[#6,#7:2][#6,#7:3]=[#6,#7:4][-0,-0:5]=[#6,#7:6]1[#6-,#7-:7]',
                  '[#6,#7:1]1=[#6,#7:2][#6,#7:3](=[#6,#7:4])[#6,#7:5]=[#6,#7:6][CX3-,NX3-:7]1>>'
                  '[#6,#7:1]1=[#6,#7:2][#6,#7:3]([#6-,#7-:4])=[#6,#7:5][#6,#7:6]=[-0,-0:7]1']

    fragments = Chem.GetMolFrags(mol,asMols=True,sanitizeFrags=False)

    for i, fragment in enumerate(fragments):
        for smarts in rxn_smarts:
            patt = Chem.MolFromSmarts(smarts.split(">>")[0])
            while fragment.HasSubstructMatch(patt):
                rxn = AllChem.ReactionFromSmarts(smarts)
                ps = rxn.RunReactants((fragment,))
                fragment = ps[0][0]
                Chem.SanitizeMol(fragment)
        if i == 0:
            mol = fragment
        else:
            mol = Chem.CombineMols(mol, fragment)

    return mol


def BO2mol(mol, BO_matrix, atoms, atomic_valence_electrons,
           mol_charge, allow_charged_fragments=True,  use_atom_maps=False):
    """
    based on code written by Paolo Toscani

    From bond order, atoms, valence structure and total charge, generate an
    rdkit molecule.

    args:
        mol - rdkit molecule
        BO_matrix - bond order matrix of molecule
        atoms - list of integer atomic symbols
        atomic_valence_electrons -
        mol_charge - total charge of molecule

    optional:
        allow_charged_fragments - bool - allow charged fragments

    returns
        mol - updated rdkit molecule with bond connectivity

    """
    l = len(BO_matrix)
    l2 = len(atoms)
    BO_valences = list(BO_matrix.sum(axis=1))

    if (l != l2):
        raise RuntimeError('sizes of adjMat ({0:d}) and Atoms {1:d} differ'.format(l, l2))

    rwMol = Chem.RWMol(mol)

    bondTypeDict = {
        1: Chem.BondType.SINGLE,
        2: Chem.BondType.DOUBLE,
        3: Chem.BondType.TRIPLE
    }

    for i in range(l):
        for j in range(i + 1, l):
            bo = int(round(BO_matrix[i, j]))
            if (bo == 0):
                continue
            bt = bondTypeDict.get(bo, Chem.BondType.SINGLE)
            rwMol.AddBond(i, j, bt)

    mol = rwMol.GetMol()

    if allow_charged_fragments:
        mol = set_atomic_charges(
            mol,
            atoms,
            atomic_valence_electrons,
            BO_valences,
            BO_matrix,
            mol_charge,
            use_atom_maps)
    else:
        mol = set_atomic_radicals(mol, atoms, atomic_valence_electrons, BO_valences,
                                                            use_atom_maps)

    return mol


def set_atomic_charges(mol, atoms, atomic_valence_electrons,
                       BO_valences, BO_matrix, mol_charge,
                       use_atom_maps):
    """
    """
    q = 0
    for i, atom in enumerate(atoms):
        a = mol.GetAtomWithIdx(i)
        if use_atom_maps:
            a.SetAtomMapNum(i+1)
        charge = get_atomic_charge(atom, atomic_valence_electrons[atom], BO_valences[i])
        q += charge
        if atom == 6:
            number_of_single_bonds_to_C = list(BO_matrix[i, :]).count(1)
            if number_of_single_bonds_to_C == 2 and BO_valences[i] == 2:
                q += 1
                charge = 0
            if number_of_single_bonds_to_C == 3 and q + 1 < mol_charge:
                q += 2
                charge = 1

        if (abs(charge) > 0):
            a.SetFormalCharge(int(charge))

    #mol = clean_charges(mol)

    return mol


def set_atomic_radicals(mol, atoms, atomic_valence_electrons, BO_valences,
                                                use_atom_maps):
    """

    The number of radical electrons = absolute atomic charge

    """
    for i, atom in enumerate(atoms):
        a = mol.GetAtomWithIdx(i)
        if use_atom_maps:
            a.SetAtomMapNum(i+1)
        charge = get_atomic_charge(
            atom,
            atomic_valence_electrons[atom],
            BO_valences[i])

        if (abs(charge) > 0):
            a.SetNumRadicalElectrons(abs(int(charge)))

    return mol


def get_bonds(UA, AC):
    """

    """
    bonds = []

    for k, i in enumerate(UA):
        for j in UA[k + 1:]:
            if AC[i, j] == 1:
                bonds.append(tuple(sorted([i, j])))

    return bonds


def get_UA_pairs(UA, AC, use_graph=True):
    """

    """
    bonds = get_bonds(UA, AC)

    if len(bonds) == 0:
        return [()]

    if use_graph:
        G = nx.Graph()
        G.add_edges_from(bonds)
        UA_pairs = [list(nx.max_weight_matching(G))]
        return UA_pairs

    max_atoms_in_combo = 0
    UA_pairs = [()]
    for combo in list(itertools.combinations(bonds, int(len(UA) / 2))):
        flat_list = [item for sublist in combo for item in sublist]
        atoms_in_combo = len(set(flat_list))
        if atoms_in_combo > max_atoms_in_combo:
            max_atoms_in_combo = atoms_in_combo
            UA_pairs = [combo]

        elif atoms_in_combo == max_atoms_in_combo:
            UA_pairs.append(combo)

    return UA_pairs


def AC2BO(AC, atoms, charge, allow_charged_fragments=True, use_graph=True):
    """

    implemenation of algorithm shown in Figure 2

    UA: unsaturated atoms

    DU: degree of unsaturation (u matrix in Figure)

    best_BO: Bcurr in Figure

    """
    global atomic_valence
    global atomic_valence_electrons

    # make a list of valences, e.g. for CO: [[4],[2,1]]
    valences_list_of_lists = []
    AC_valence = list(AC.sum(axis=1))
    
    for i,(atomicNum,valence) in enumerate(zip(atoms,AC_valence)):
        # valence can't be smaller than number of neighbourgs
        possible_valence = [x for x in atomic_valence[atomicNum] if x >= valence]
        if not possible_valence:
            print('Valence of atom',i,'is',valence,'which bigger than allowed max',max(atomic_valence[atomicNum]),'. Stopping')
            sys.exit()
        valences_list_of_lists.append(possible_valence)

    # convert [[4],[2,1]] to [[4,2],[4,1]]
    valences_list = itertools.product(*valences_list_of_lists)

    best_BO = AC.copy()

    for valences in valences_list:

        UA, DU_from_AC = get_UA(valences, AC_valence)

        check_len = (len(UA) == 0)
        if check_len:
            check_bo = BO_is_OK(AC, AC, charge, DU_from_AC,
                atomic_valence_electrons, atoms, valences,
                allow_charged_fragments=allow_charged_fragments)
        else:
            check_bo = None

        if check_len and check_bo:
            return AC, atomic_valence_electrons

        UA_pairs_list = get_UA_pairs(UA, AC, use_graph=use_graph)
        for UA_pairs in UA_pairs_list:
            BO = get_BO(AC, UA, DU_from_AC, valences, UA_pairs, use_graph=use_graph)
            status = BO_is_OK(BO, AC, charge, DU_from_AC,
                        atomic_valence_electrons, atoms, valences,
                        allow_charged_fragments=allow_charged_fragments)
            charge_OK = charge_is_OK(BO, AC, charge, DU_from_AC, atomic_valence_electrons, atoms, valences,
                                     allow_charged_fragments=allow_charged_fragments)

            if status:
                return BO, atomic_valence_electrons
            elif BO.sum() >= best_BO.sum() and valences_not_too_large(BO, valences) and charge_OK:
                best_BO = BO.copy()

    return best_BO, atomic_valence_electrons


def AC2mol(mol, AC, atoms, charge, allow_charged_fragments=True, 
           use_graph=True, use_atom_maps=False):
    """
    """
    lg = RDLogger.logger()

    lg.setLevel(RDLogger.CRITICAL)

    # convert AC matrix to bond order (BO) matrix
    BO, atomic_valence_electrons = AC2BO(
        AC,
        atoms,
        charge,
        allow_charged_fragments=allow_charged_fragments,
        use_graph=use_graph)

    # add BO connectivity and charge info to mol object
    mol = BO2mol(
        mol,
        BO,
        atoms,
        atomic_valence_electrons,
        charge,
        allow_charged_fragments=allow_charged_fragments,
        use_atom_maps=use_atom_maps)

    # If charge is not correct don't return mol
    if Chem.GetFormalCharge(mol) != charge:
        return []

    # BO2mol returns an arbitrary resonance form. Let's make the rest
    mols = rdchem.ResonanceMolSupplier(mol, Chem.UNCONSTRAINED_CATIONS, Chem.UNCONSTRAINED_ANIONS)
    mols = [mol for mol in mols]

    return mols


def get_proto_mol(atoms):
    """
    """
    lg = RDLogger.logger()

    lg.setLevel(RDLogger.WARNING)

    mol = Chem.MolFromSmarts("[#" + str(atoms[0]) + "]")
    rwMol = Chem.RWMol(mol)
    for i in range(1, len(atoms)):
        a = Chem.Atom(atoms[i])
        rwMol.AddAtom(a)

    mol = rwMol.GetMol()

    return mol


def read_xyz_file(filename, look_for_charge=True):
    """
    """
    lg = RDLogger.logger()

    lg.setLevel(RDLogger.CRITICAL)

    atomic_symbols = []
    xyz_coordinates = []
    charge = 0
    title = ""

    with open(filename, "r") as file:
        for line_number, line in enumerate(file):
            if line_number == 0:
                num_atoms = int(line)
            elif line_number == 1:
                title = line
                if "charge=" in line:
                    charge = int(line.split("=")[1])
            else:
                atomic_symbol, x, y, z = line.split()
                atomic_symbols.append(atomic_symbol)
                xyz_coordinates.append([float(x), float(y), float(z)])

    atoms = [int_atom(atom) for atom in atomic_symbols]

    return atoms, charge, xyz_coordinates


def xyz2AC(atoms, xyz, charge, use_huckel=False):
    """

    atoms and coordinates to atom connectivity (AC)

    args:
        atoms - int atom types
        xyz - coordinates
        charge - molecule charge

    optional:
        use_huckel - Use Huckel method for atom connecitivty

    returns
        ac - atom connectivity matrix
        mol - rdkit molecule

    """
    lg = RDLogger.logger()

    lg.setLevel(RDLogger.CRITICAL)

    if use_huckel:
        return xyz2AC_huckel(atoms, xyz, charge)
    else:
        return xyz2AC_vdW(atoms, xyz)


def xyz2AC_vdW(atoms, xyz):
    lg = RDLogger.logger()

    lg.setLevel(RDLogger.CRITICAL)

    # Get mol template
    mol = get_proto_mol(atoms)

    # Set coordinates
    conf = Chem.Conformer(mol.GetNumAtoms())
    for i in range(mol.GetNumAtoms()):
        conf.SetAtomPosition(i, (xyz[i][0], xyz[i][1], xyz[i][2]))
    mol.AddConformer(conf)

    AC = get_AC(mol)

    return AC, mol


def get_AC(mol, covalent_factor=1.3):
    """

    Generate adjacent matrix from atoms and coordinates.

    AC is a (num_atoms, num_atoms) matrix with 1 being covalent bond and 0 is not


    covalent_factor - 1.3 is an arbitrary factor

    args:
        mol - rdkit molobj with 3D conformer

    optional
        covalent_factor - increase covalent bond length threshold with facto

    returns:
        AC - adjacent matrix

    """
    lg = RDLogger.logger()

    lg.setLevel(RDLogger.CRITICAL)

    # Calculate distance matrix
    dMat = Chem.Get3DDistanceMatrix(mol)

    pt = Chem.GetPeriodicTable()
    num_atoms = mol.GetNumAtoms()
    AC = np.zeros((num_atoms, num_atoms), dtype=int)

    for i in range(num_atoms):
        a_i = mol.GetAtomWithIdx(i)
        Rcov_i = pt.GetRcovalent(a_i.GetAtomicNum()) * covalent_factor
        for j in range(i + 1, num_atoms):
            a_j = mol.GetAtomWithIdx(j)
            Rcov_j = pt.GetRcovalent(a_j.GetAtomicNum()) * covalent_factor
            if dMat[i, j] <= Rcov_i + Rcov_j:
                AC[i, j] = 1
                AC[j, i] = 1

    return AC


def xyz2AC_huckel(atomicNumList, xyz, charge):
    """

    args
        atomicNumList - atom type list
        xyz - coordinates
        charge - molecule charge

    returns
        ac - atom connectivity
        mol - rdkit molecule

    """
    lg = RDLogger.logger()

    lg.setLevel(RDLogger.CRITICAL)

    mol = get_proto_mol(atomicNumList)

    conf = Chem.Conformer(mol.GetNumAtoms())
    for i in range(mol.GetNumAtoms()):
        conf.SetAtomPosition(i,(xyz[i][0],xyz[i][1],xyz[i][2]))
    mol.AddConformer(conf)

    num_atoms = len(atomicNumList)
    AC = np.zeros((num_atoms,num_atoms)).astype(int)

    mol_huckel = Chem.Mol(mol)
    mol_huckel.GetAtomWithIdx(0).SetFormalCharge(charge) #mol charge arbitrarily added to 1st atom    

    passed,result = rdEHTTools.RunMol(mol_huckel)
    opop = result.GetReducedOverlapPopulationMatrix()
    tri = np.zeros((num_atoms, num_atoms))
    tri[np.tril(np.ones((num_atoms, num_atoms), dtype=bool))] = opop #lower triangular to square matrix
    for i in range(num_atoms):
        for j in range(i+1,num_atoms):
            pair_pop = abs(tri[j,i])   
            if pair_pop >= 0.15: #arbitry cutoff for bond. May need adjustment
                AC[i,j] = 1
                AC[j,i] = 1
        
    return AC, mol


def chiral_stereo_check(mol):
    """
    Find and embed chiral information into the model based on the coordinates

    args:
        mol - rdkit molecule, with embeded conformer

    """
    Chem.SanitizeMol(mol)
    Chem.DetectBondStereochemistry(mol, -1)
    Chem.AssignStereochemistry(mol, flagPossibleStereoCenters=True, force=True)
    Chem.AssignAtomChiralTagsFromStructure(mol, -1)

    return


def xyz2mol(atoms, coordinates, charge=0, allow_charged_fragments=True,
            use_graph=True, use_huckel=False, embed_chiral=True,
            use_atom_maps=False):
    """
    Generate a rdkit molobj from atoms, coordinates and a total_charge.

    args:
        atoms - list of atom types (int)
        coordinates - 3xN Cartesian coordinates
        charge - total charge of the system (default: 0)

    optional:
        allow_charged_fragments - alternatively radicals are made
        use_graph - use graph (networkx)
        use_huckel - Use Huckel method for atom connectivity prediction
        embed_chiral - embed chiral information to the molecule

    returns:
        mols - list of rdkit molobjects

    """
    lg = RDLogger.logger()

    lg.setLevel(RDLogger.CRITICAL)

    # Get atom connectivity (AC) matrix, list of atomic numbers, molecular charge,
    # and mol object with no connectivity information
    AC, mol = xyz2AC(atoms, coordinates, charge, use_huckel=use_huckel)

    # Convert AC to bond order matrix and add connectivity and charge info to
    # mol object
    new_mols = AC2mol(mol, AC, atoms, charge,
                     allow_charged_fragments=allow_charged_fragments,
                     use_graph=use_graph,
                     use_atom_maps=use_atom_maps)

    # Check for stereocenters and chiral centers
    if embed_chiral:
        for new_mol in new_mols:
            chiral_stereo_check(new_mol)

    return new_mols

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
def init_aev_computer():
    Rcr = 5.2
    Rca = 3.5
    EtaR = torch.tensor([16], dtype=torch.float, device=device)
    ShfR = torch.tensor([
        0.900000, 1.168750, 1.437500, 1.706250, 
        1.975000, 2.243750, 2.512500, 2.781250, 
        3.050000, 3.318750, 3.587500, 3.856250, 
        4.125000, 4.393750, 4.662500, 4.931250
    ], dtype=torch.float, device=device)


    EtaA = torch.tensor([8], dtype=torch.float, device=device)
    Zeta = torch.tensor([32], dtype=torch.float, device=device)
    ShfA = torch.tensor([0.90, 1.55, 2.20, 2.85], dtype=torch.float, device=device)
    ShfZ = torch.tensor([
        0.19634954, 0.58904862, 0.9817477, 1.37444680, 
        1.76714590, 2.15984490, 2.5525440, 2.94524300
    ], dtype=torch.float, device=device)

    num_species = 4
    aev_computer = torchani.AEVComputer(
        Rcr, Rca, EtaR, ShfR, EtaA, Zeta, ShfA, ShfZ, num_species
    )
    return aev_computer

aev_computer = init_aev_computer()
aev_dim = aev_computer.aev_length
print(aev_dim)

# %%
def load_ani_dataset(dspath):

    
    self_energies = torch.tensor([
        0.500607632585, -37.8302333826,
        -54.5680045287, -75.0362229210
    ], dtype=torch.float, device=device)
    energy_shifter = torchani.utils.EnergyShifter(None)
    species_order = ['H', 'C', 'N', 'O']
    
    dataset = torchani.data.load(dspath)
    dataset = dataset.subtract_self_energies(energy_shifter, species_order)
    dataset = dataset.species_to_indices(species_order)
    dataset = dataset.shuffle()
    return dataset

dataset = load_ani_dataset("/global/scratch/users/timp/datasets/ani_gdb_s01_to_s04.h5")
print(dataset)
# Use dataset.split method to do split
train_data, val_data, test_data = dataset.split(0.8, 0.1, 0.1)
# Out:
# <torchani.data.TransformableIterable object at 0x2b37d9fd6dd0>

# %%
batch_size = 8192
# use dataset.collate(...).cache() method to do batching
train_data_loader = train_data.collate(batch_size).cache()
val_data_loader = val_data.collate(batch_size).cache()
test_data_loader = test_data.collate(batch_size).cache()

# %%
def preprocess_data(item):
    lg = RDLogger.logger()

    lg.setLevel(RDLogger.CRITICAL)

    species_labels = [[1, 6, 7, 8][i] for i in item['species']]
    coord_list = item['coordinates'].tolist()
    energy = item['energies'].tolist()
    
    encoder = GraphEncoder()
    try:

        mol = xyz2mol(species_labels, coord_list, 0, use_huckel=True)
        if mol is None:
            return None
    except SystemExit:
        print("Error: xyz2mol function raised SystemExit")
        return None
    if len(mol) == 1:
        node_features, edge_features, edge_index = encoder.encode(mol[0])
        return Data(x=node_features, edge_attr=edge_features, edge_index=edge_index, y=energy)

def create_dataloader(dataset, batch_size=8192, shuffle=True):
    lg = RDLogger.logger()

    lg.setLevel(RDLogger.CRITICAL)

    preprocessed_data = [preprocess_data(item) for item in dataset]
    filtered_data = list(filter(lambda x: x is not None, preprocessed_data))
    dataloader = GraphDataLoader(filtered_data, batch_size=batch_size, shuffle=shuffle)

    return dataloader
    return preprocessed_data

# %%
def one_hot_encode(species):
    categories = [0, 1, 2, 3]
    num_samples = len(species)
    num_categories = len(categories)
    node_feature = torch.zeros((num_samples, num_categories), dtype=torch.float32)
    for i, s in enumerate(species):
        if s in categories:
            idx = categories.index(s)
            node_feature[i, idx] = 1
    
    return node_feature

def transform(d):
    coords = torch.tensor(d['coordinates'], dtype=torch.float32)
    species = torch.tensor(d['species'], dtype=torch.float32)
    energy = torch.tensor(d['energies'], dtype=torch.float32)
    
    node_feature = one_hot_encode(d['species'])
    edge_index = torch.tensor(
        list(itertools.permutations(range(coords.shape[0]), 2)), 
    ).T
    edge_feature = 1 / torch.sqrt(
        torch.sum(
            (coords[edge_index[0]] - coords[edge_index[1]]) ** 2, 
            axis=1, keepdim=True
        )
    )

    graph_data = Data(x=node_feature,
                 edge_index=edge_index,
                 edge_attr=edge_feature,
                 y=energy
                     )
    return graph_data

# %%
batch_size = 2048

# %%
graph_ani_train = [transform(d) for d in train_data]

# %%
graph_ani_test = [transform(d) for d in test_data]

# %%
graph_ani_val = [transform(d) for d in val_data]

# %%
graph_ani_train_loader = GraphDataLoader(graph_ani_train, batch_size=batch_size, shuffle=True)

# %%
graph_ani_test_loader = GraphDataLoader(graph_ani_test, batch_size=batch_size, shuffle=True)

# %%
graph_ani_val_loader = GraphDataLoader(graph_ani_val, batch_size=batch_size, shuffle=True)

# %%
class GraphEncoder:
    def __init__(self):
        self.node_features = torch.empty(0, dtype=torch.float32)
        self.edge_features = torch.empty(0, dtype=torch.float32)
        self.adjacency_matrix = None
    


    def encode(self, mol):
        #compute partial charges, I want to use these as a feature.  
        #Might make sense to normalize them and use the charge distribution as node features,
        #as opposed to the 
        if mol is None:
            return None
        for atom in mol.GetAtoms():
            atom_feat = self.encode_atom(atom)
            self.node_features = torch.cat((self.node_features, atom_feat.unsqueeze(0)), dim=0)
        #Extract edge features from bonds
        for bond in mol.GetBonds():
            bond_feat = self.encode_bond(bond)
            self.edge_features = torch.cat((self.edge_features, bond_feat.unsqueeze(0)), dim=0)

        self.adjacency_matrix = torch.tensor(Chem.GetAdjacencyMatrix(mol), dtype=torch.float32)
        row_indices, col_indices = torch.nonzero(self.adjacency_matrix.triu(), as_tuple=True)

        #Get edge_indices
        self.edge_index = torch.stack([row_indices, col_indices], dim=0)
        
        return self.node_features, self.edge_features, self.edge_index

    def encode_atom(self, atom):
        #One hot encode hybridization, whether atom is in aromatic system, whether it is in ring system,
        #and the atomic number.
        atom_num = atom.GetAtomicNum()
        atom_hybridization = self.one_hot_encode(str(atom.GetHybridization()), ['S', 'SP', 'SP2', 'SP3'])
        #atom_aromaticity = self.one_hot_encode(int(atom.GetIsAromatic()), [1, 0])
        #atom_ring = self.one_hot_encode(int(atom.IsInRing()), [1, 0])
        atom_type = self.one_hot_encode(int(atom.GetAtomicNum()), [8, 7, 6, 1])
        #I am using the scaled mass, VdW and covalent radii as 'continuous' node features.
        atom_feat = torch.cat(( #One-hot-encoded properties
            atom_hybridization, 
            #atom_aromaticity, aromaticity irrelevant with 4 heavy atoms
            #atom_ring, presence in ring is irrelevant with 4 heavy atoms
            atom_type, 
            torch.tensor([ #floating point properties
                atom.GetMass()/15.999,
                Chem.GetPeriodicTable().GetRvdw(atom_num),
                Chem.GetPeriodicTable().GetRcovalent(atom_num)
            ], dtype=torch.float32)))

        return atom_feat

    def encode_bond(self, bond):
        #one hot encode a few binary properties and the bond type (single, double, etc). 
        #bond 'type' of 1.5 implies an aromatic bond (like in benzene (this is the hexagon molecule with three lines))
        bond_conj = int(bond.GetIsConjugated())
        #bond_aromaticity = self.one_hot_encode(int(bond.GetIsAromatic()), [1, 0])
        bond_type_oh = self.one_hot_encode(bond.GetBondTypeAsDouble(), [1.5, 1.0, 2.0, 3.0])
        #print(f"encoded bond type: {bond_type_oh}")
        bond_feat = torch.cat((
            torch.tensor([
                bond_conj
                         ], dtype=torch.float32), 
            #bond_aromaticity, bond aromaticity is irrelevant with only four heavy atoms
            bond_type_oh
        ))

        return bond_feat

    def one_hot_encode(self, value, options):
        #Might make sense to reimplement using scipy one hot encoder
        encoded = torch.zeros(len(options))
        if value in options:
            encoded[options.index(value)] = 1
        
        return encoded
        

    #def get_graph_representation(self):
        #This function unnecessary unless I want to make a adjacency matrix representation.
    #    return self.node_features, self.edge_features, self.adjacency_matrix

# %%
node_hidden_dim = 128
edge_hidden_dim = 128

net = GraphNet(node_input_dim, edge_input_dim, node_hidden_dim, edge_hidden_dim).to(device)

# %%
class Layer(nn.Module):
    """
    Basic layer, a linear layer with a ReLU activation 
    """
    def __init__(self, in_dim, out_dim):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(in_dim, out_dim), # linear layer
            nn.LeakyReLU() # relu
        )
    
    def forward(self, x):
        return self.layers(x)
    
    
class MessagePassingLayer(nn.Module):
    """
    A message passing layer that updates nodes/edge features
    """
    def __init__(self, node_hidden_dim, edge_hidden_dim):
        super().__init__()
        # figure out the input/output dimension
        self.edge_net = Layer(2 * node_hidden_dim + edge_hidden_dim, edge_hidden_dim)
        # figure out the input/output dimension
        self.node_net = Layer(node_hidden_dim + edge_hidden_dim, node_hidden_dim)
    
    def forward(self, node_features, edge_features, edge_index):
        """
        Update node and edge features
        
        Parameters
        ----------
        node_features: torch.Tensor
            Node features from the previous layer
        edge_features: torch.Tensor
            Edge features from the previous layer
        edge_index: torch.Tensor
            A sparse matrix (n_edge, 2) in which each column denotes node indices forming an edge
        """
        # concatnate previous edge features with node features forming the edge
        # hint: use node_features[edge_index[0(or 1)]] to get node features forming the edge
        concate_edge_features = torch.cat([
            node_features[edge_index[0]], # features of one node
            node_features[edge_index[1]], # features of the other node
            edge_features # previous edge features
        ], dim=1)
        
        # pass through the "edge_net" to map it back to the original dimension
        updated_edge_features = self.edge_net(concate_edge_features)
        
        
        # use scatter to aggrate the edge features to nodes
        aggr_edge_features = scatter(updated_edge_features, edge_index[0], dim_size=node_features.size(0))
        # concatenate it with previous node features
        concate_node_features = torch.cat([aggr_edge_features, node_features], dim=1)
        # pass through the "node_net" to map it back to the original dimension
        updated_node_features = self.node_net(concate_node_features)
        
        return updated_node_features, updated_edge_features

#class GraphConvBlock(nn.Module):
#    def__init__(self, 


class GraphNet(nn.Module):
    def __init__(self, node_input_dim, edge_input_dim, node_hidden_dim, edge_hidden_dim):
        super().__init__()
        # embed the input node features
        self.node_embed = Layer(node_input_dim, node_hidden_dim)
        # embed the input edge features
        self.edge_embed = Layer(edge_input_dim, edge_hidden_dim)
        # use a linear layer as readout to get the "atomic" energy contribution
        self.readout = nn.Linear(node_hidden_dim, 1)
        # message passing layer
        self.message_passing = MessagePassingLayer(node_hidden_dim, edge_hidden_dim)
    
    def forward(self, node_features, edge_features, edge_index, batch):
        """
        Update node and edge features
        
        Parameters
        ----------
        node_features: torch.Tensor
            Node features from the previous layer
        edge_features: torch.Tensor
            Edge features from the previous layer
        edge_index: torch.Tensor
            A sparse matrix (n_edges, 2) in which each column denotes node indices forming an edge
        batch: torch.Tensor
            A 1-D tensor (n_nodes,) that tells you each node belongs to which graph
        """
        node_hidden = self.node_embed(node_features) # call the node embedding
        edge_hidden = self.edge_embed(edge_features) # call the edge embedding
        #node_hidden = self.conv_block(node_hidden, edge_index)
        updated_node_hidden, updated_edge_hidden = self.message_passing(
            node_hidden,
            edge_hidden,
            edge_index
        ) # call the message passing layer
        readout = self.readout(updated_node_hidden) # use the readout layer to output "atomic" contributions
        out = scatter(readout, batch.to(readout.device)) # use the scatter function to aggregate atomic readouts
        return out

# %%
class GNNTrainer:
    def __init__(self, model, batch_size, learning_rate, epoch, l2):
        self.model = model.to(device)
        self.loss = nn.MSELoss()
        
        num_params = sum(item.numel() for item in model.parameters())
        print(f"{model.__class__.__name__} - Number of parameters: {num_params}")
        
        self.batch_size = batch_size
        self.optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=l2)
        self.epoch = epoch

    def train(self, train_loader, val_loader, early_stop=True, draw_curve=True):
        self.model.train()
        train_loss_list, val_loss_list, lowest_val_loss = [], [], np.inf
        #loader = GraphDataLoader(dataset, batch_size=self.batch_size, shuffle=True)
        
        loss_func = self.loss
        batch_loss_list = []
        for i in tqdm(range(self.epoch)):
            train_epoch_loss = 0.0
            #print(f"Epoch: {i}")

            for batch_data in train_loader:
                batch_size = batch_data.y.shape[0]
                node_features = batch_data.x.to(device)
                edge_features = batch_data.edge_attr.to(device)
                edge_index = batch_data.edge_index.to(device)
                batch_pred = self.model(node_features, edge_features, edge_index, batch_data.batch).to(device)
                batch_loss = loss_func(batch_pred, batch_data.y.unsqueeze(1).float())

                self.optimizer.zero_grad()
                batch_loss.backward()
                self.optimizer.step()

                batch_importance = batch_pred.shape[0]/len(train_loader.dataset)
                batch_loss_list.append(batch_loss.detach().cpu().numpy())
                train_epoch_loss += batch_loss.detach().to(device).item()*batch_importance

            val_epoch_loss = self.evaluate(val_loader, draw_plot=False)
            train_loss_list.append(train_epoch_loss)
            val_loss_list.append(val_epoch_loss)

            if early_stop:
                if val_epoch_loss < lowest_val_loss:
                    lowest_val_loss = val_epoch_loss
                    weights = self.model.state_dict()
        
        if draw_curve:
            fig, ax = plt.subplots(1, 1, figsize=(5, 4), constrained_layout=True)
            ax.set_yscale("log")
            x_axis = np.arange(self.epoch)
            # Plot train loss and validation loss
            ax.plot(x_axis, train_loss_list, label='Train')
            ax.plot(x_axis, val_loss_list, label='Validation')
            ax.legend()
            ax.set_xlabel("# Batch")
            ax.set_ylabel("Loss")
        
        if early_stop:
            self.model.load_state_dict(weights)
        
        
        return batch_loss_list
    
    def evaluate(self, loader, draw_plot=True):
        self.model.eval()
        #loader = GraphDataLoader(dataset, batch_size=self.batch_size)
        true_energies_all, pred_energies_all = [], []
        loss_func = self.loss
        total_loss = 0.0

        
        with torch.no_grad():
            for batch_data in loader:
                node_features = batch_data.x.to(device)
                edge_features = batch_data.edge_attr.to(device)
                edge_index = batch_data.edge_index.to(device)
                batch = batch_data.batch
                batch_pred = self.model(node_features, edge_features, edge_index, batch).to(device)
                #print(f"batch_pred: {batch_pred}")
                batch_true = batch_data.y.to(device)
                batch_loss = loss_func(batch_pred, batch_true.unsqueeze(1).float())
                #print(f"batch_true: {batch_true}")
                
                batch_importance = 1 / len(loader.dataset)
                
                total_loss += batch_loss.detach().to(device).item() * batch_importance
                
                if draw_plot:
                    pred_energies_all.append(batch_pred.detach().cpu().numpy().flatten())
                    true_energies_all.append(batch_data.y.detach().cpu().numpy().flatten())
                
        
        
        
        if draw_plot:
            true_energies_all = np.concatenate(true_energies_all)
            pred_energies_all = np.concatenate(pred_energies_all)
            hartree2kcalmol = 627.5094738898777
            mae = np.mean(np.abs(true_energies_all - pred_energies_all)) * hartree2kcalmol
            #mse = np.mean((true_energies_all - pred_energies_all) ** 2)
            fig, ax = plt.subplots(1, 1, figsize=(5, 4), constrained_layout=True)
            ax.scatter(true_energies_all, pred_energies_all, label=f"MAE: {mae:.2f}", s=2)
            ax.set_xlabel("Ground Truth")
            ax.set_ylabel("Predicted")
            xmin, xmax = ax.get_xlim()
            ymin, ymax = ax.get_ylim()
            vmin, vmax = min(xmin, ymin), max(xmax, ymax)
            ax.set_xlim(vmin, vmax)
            ax.set_ylim(vmin, vmax)
            ax.plot([vmin, vmax], [vmin, vmax], color='red')
            ax.legend()
            
        return total_loss

# %%
lg.setLevel(RDLogger.ERROR)
RDLogger.logger().setLevel(RDLogger.CRITICAL)

# %%
train_1, train_2, train_3, train_4 = train_data.split(0.25, 0.25, 0.25, 0.25)

# %%
lg.setLevel(RDLogger.ERROR)
RDLogger.logger().setLevel(RDLogger.CRITICAL)

graph_train_1 = create_dataloader(train_1)

torch.save(graph_train_1.dataset, '/global/scratch/users/timp/datasets/graph_train_data_1.pt')
# Out:
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 8 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit

# %%
lg.setLevel(RDLogger.ERROR)
RDLogger.logger().setLevel(RDLogger.CRITICAL)

graph_train_2 = create_dataloader(train_2)

torch.save(graph_train_2.dataset, '/global/scratch/users/timp/datasets/graph_train_data_2.pt')
# Out:
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 2 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit

# %%
lg.setLevel(RDLogger.ERROR)
RDLogger.logger().setLevel(RDLogger.CRITICAL)

graph_train_3 = create_dataloader(train_3)

torch.save(graph_train_3.dataset, '/global/scratch/users/timp/datasets/graph_train_data_3.pt')
# Out:
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit

# %%
lg.setLevel(RDLogger.ERROR)
RDLogger.logger().setLevel(RDLogger.CRITICAL)

graph_train_4 = create_dataloader(train_4)

torch.save(graph_train_4.dataset, '/global/scratch/users/timp/datasets/graph_train_data_4.pt')
# Out:
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 9 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 8 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit

# %%
lg.setLevel(RDLogger.ERROR)
graph_val = create_dataloader(val_data)
torch.save(graph_val.dataset, '/global/scratch/users/timp/datasets/graph_val_data.pt')
# Out:
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 9 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit

# %%
lg.setLevel(RDLogger.ERROR)
graph_test = create_dataloader(test_data)
torch.save(graph_test.dataset, '/global/scratch/users/timp/datasets/graph_test_data.pt')
# Out:
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 5 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit
# Valence of atom 4 is 2 which bigger than allowed max 1 . Stopping
# Error: xyz2mol function raised SystemExit

# %%
torch.save(graph_test, 'graph_test.pt')

# %%
def make_dataloader(dataset, batch_size=8192, shuffle=True):
    
    filtered_data = list(filter(lambda x: x is not None, dataset))
    dataloader = GraphDataLoader(filtered_data, batch_size=batch_size, shuffle=shuffle)

    return dataloader

def move_data_to_device(dataloader, device):
    for data in dataloader.dataset:
        data = data.to(device)
        data.y = data.y.to(device)

# %%
graph_test = make_dataloader(torch.load('/global/scratch/users/timp/datasets/graph_test_data.pt'))
graph_val = make_dataloader(torch.load('/global/scratch/users/timp/datasets/graph_val_data.pt'))
graph_train = make_dataloader(torch.utils.data.ConcatDataset([
    torch.load('/global/scratch/users/timp/datasets/graph_train_data_1.pt'),
    torch.load('/global/scratch/users/timp/datasets/graph_train_data_2.pt'),
    torch.load('/global/scratch/users/timp/datasets/graph_train_data_3.pt'),
    torch.load('/global/scratch/users/timp/datasets/graph_train_data_4.pt')
]))
move_data_to_device(graph_test, device)
move_data_to_device(graph_train, device)
move_data_to_device(graph_val, device)

# %%
move_data_to_device(graph_ani_train_loader, device)
move_data_to_device(graph_ani_test_loader, device)
move_data_to_device(graph_ani_val_loader, device)

# %% [markdown]
# Yes, it would be much more efficient to just specify the device upon the creation of tensors.  I should have done this, but because of how much things crashed, I didn't have enough computation time to re-load datasets after I realized this.

# %%
node_input_dim = graph_ani_train[0].x.shape[1]
edge_input_dim = 1
node_input_dim
# Out:
# 4

# %%
node_hidden_dim = 64
edge_hidden_dim = 64

net = GraphNet(node_input_dim, edge_input_dim, node_hidden_dim, edge_hidden_dim).to(device)

# %%
# train 
learning_rate = 1e-3
n_epoch = 50
batch_size = 2048
l2 = 1e-4

trainer = GNNTrainer(net, batch_size, learning_rate, n_epoch, l2)
trainer.train(graph_ani_train_loader, graph_ani_val_loader)
# Out:
# GraphNet - Number of parameters: 21121
# 100%|██████████| 50/50 [1:00:58<00:00, 73.17s/it]
# [array(9.4736475e-05, dtype=float32),
#  array(0.03335124, dtype=float32),
#  array(0.00048203, dtype=float32),
#  array(0.01572936, dtype=float32),
#  array(0.00253688, dtype=float32),
#  array(0.01495201, dtype=float32),
#  array(0.00184106, dtype=float32),
#  array(0.00373225, dtype=float32),
#  array(0.00628277, dtype=float32),
#  array(0.00316147, dtype=float32),
#  array(0.00072395, dtype=float32),
#  array(0.00198938, dtype=float32),
#  array(0.00371936, dtype=float32),
#  array(0.00289944, dtype=float32),
#  array(0.00101576, dtype=float32),
#  array(0.00107292, dtype=float32),
#  array(0.00201335, dtype=float32),
#  array(0.00223499, dtype=float32),
#  array(0.00142538, dtype=float32),
#  array(0.00073043, dtype=float32),
#  array(0.00078579, dtype=float32),
#  array(0.00109339, dtype=float32),
#  array(0.0012474, dtype=float32),
#  array(0.00102158, dtype=float32),
#  array(0.00071617, dtype=float32),
#  array(0.00052864, dtype=float32),
#  array(0.00098569, dtype=float32),
#  array(0.00083655, dtype=float32),
#  array(0.00076124, dtype=float32),
#  array(0.00064268, dtype=float32),
#  array(0.0003839, dtype=float32),
#  array(0.00049325, dtype=float32),
#  array(0.00063596, dtype=float32),
#  array(0.0006073, dtype=float32),
#  array(0.00044284, dtype=float32),
#  array(0.00041526, dtype=float32),
#  array(0.00044431, dtype=float32),
#  array(0.00043145, dtype=float32),
#  array(0.00044483, dtype=float32),
#  array(0.00041651, dtype=float32),
#  array(0.00032743, dtype=float32),
#  array(0.00037886, dtype=float32),
#  array(0.00038863, dtype=float32),
#  array(0.0004491, dtype=float32),
#  array(0.00037085, dtype=float32),
#  array(0.00031987, dtype=float32),
#  array(0.00033787, dtype=float32),
#  array(0.00035657, dtype=float32),
#  array(0.00031386, dtype=float32),
#  array(0.00030014, dtype=float32),
#  array(0.00036389, dtype=float32),
#  array(0.00036927, dtype=float32),
#  array(0.00029757, dtype=float32),
#  array(0.00024625, dtype=float32),
#  array(0.00030559, dtype=float32),
#  array(0.00029604, dtype=float32),
#  array(0.00035391, dtype=float32),
#  array(0.00030368, dtype=float32),
#  array(0.00022091, dtype=float32),
#  array(0.00022582, dtype=float32),
#  array(0.00026985, dtype=float32),
#  array(0.00026942, dtype=float32),
#  array(0.00028311, dtype=float32),
#  array(0.00023959, dtype=float32),
#  array(0.00022266, dtype=float32),
#  array(0.00020888, dtype=float32),
#  array(0.00027665, dtype=float32),
#  array(0.00026003, dtype=float32),
#  array(0.00020429, dtype=float32),
#  array(0.00033707, dtype=float32),
#  array(0.00024272, dtype=float32),
#  array(0.00027644, dtype=float32),
#  array(0.00020719, dtype=float32),
#  array(0.0001986, dtype=float32),
#  array(0.00025412, dtype=float32),
#  array(0.00024139, dtype=float32),
#  array(0.00024252, dtype=float32),
#  array(0.00023671, dtype=float32),
#  array(0.00022924, dtype=float32),
#  array(0.00023489, dtype=float32),
#  array(0.00021068, dtype=float32),
#  array(0.00023822, dtype=float32),
#  array(0.00019525, dtype=float32),
#  array(0.00023179, dtype=float32),
#  array(0.00019489, dtype=float32),
#  array(0.00021937, dtype=float32),
#  array(0.0001967, dtype=float32),
#  array(0.00020044, dtype=float32),
#  array(0.00024412, dtype=float32),
#  array(0.00019821, dtype=float32),
#  array(0.00017686, dtype=float32),
#  array(0.0002107, dtype=float32),
#  array(0.00024133, dtype=float32),
#  array(0.00022673, dtype=float32),
#  array(0.00018982, dtype=float32),
#  array(0.00016864, dtype=float32),
#  array(0.00016641, dtype=float32),
#  array(0.00020772, dtype=float32),
#  array(0.00017948, dtype=float32),
#  array(0.00023415, dtype=float32),
#  array(0.00017405, dtype=float32),
#  array(0.00017704, dtype=float32),
#  array(0.0001571, dtype=float32),
#  array(0.0001625, dtype=float32),
#  array(0.00016988, dtype=float32),
#  array(0.00016201, dtype=float32),
#  array(0.00016847, dtype=float32),
#  array(0.00018163, dtype=float32),
#  array(0.00022475, dtype=float32),
#  array(0.00018686, dtype=float32),
#  array(0.00019324, dtype=float32),
#  array(0.0001682, dtype=float32),
#  array(0.00023198, dtype=float32),
#  array(0.00015023, dtype=float32),
#  array(0.00019776, dtype=float32),
#  array(0.00015075, dtype=float32),
#  array(0.00019319, dtype=float32),
#  array(0.00016693, dtype=float32),
#  array(0.00014843, dtype=float32),
#  array(0.00018786, dtype=float32),
#  array(0.00018726, dtype=float32),
#  array(0.00016516, dtype=float32),
#  array(0.00014628, dtype=float32),
#  array(0.00015221, dtype=float32),
#  array(0.00016064, dtype=float32),
#  array(0.00015479, dtype=float32),
#  array(0.00015649, dtype=float32),
#  array(0.0001543, dtype=float32),
#  array(0.00015628, dtype=float32),
#  array(0.00015056, dtype=float32),
#  array(0.00013407, dtype=float32),
#  array(0.00015374, dtype=float32),
#  array(0.0001819, dtype=float32),
#  array(0.00012977, dtype=float32),
#  array(0.00014371, dtype=float32),
#  array(0.00013325, dtype=float32),
#  array(0.00015679, dtype=float32),
#  array(0.0001502, dtype=float32),
#  array(0.00013272, dtype=float32),
#  array(0.00014007, dtype=float32),
#  array(0.00014707, dtype=float32),
#  array(0.00015516, dtype=float32),
#  array(0.00014784, dtype=float32),
#  array(0.00013835, dtype=float32),
#  array(0.0001318, dtype=float32),
#  array(0.00014744, dtype=float32),
#  array(0.00015231, dtype=float32),
#  array(0.00017414, dtype=float32),
#  array(0.00017108, dtype=float32),
#  array(0.00013077, dtype=float32),
#  array(0.00016112, dtype=float32),
#  array(0.00012731, dtype=float32),
#  array(0.00011843, dtype=float32),
#  array(0.00012795, dtype=float32),
#  array(0.00013304, dtype=float32),
#  array(0.00011335, dtype=float32),
#  array(0.0001226, dtype=float32),
#  array(0.00010893, dtype=float32),
#  array(0.00010382, dtype=float32),
#  array(0.00012744, dtype=float32),
#  array(0.0001114, dtype=float32),
#  array(0.00011316, dtype=float32),
#  array(0.00011352, dtype=float32),
#  array(0.00010555, dtype=float32),
#  array(0.00012683, dtype=float32),
#  array(0.00011431, dtype=float32),
#  array(0.00011221, dtype=float32),
#  array(0.00012252, dtype=float32),
#  array(0.00011112, dtype=float32),
#  array(0.00011236, dtype=float32),
#  array(0.00011289, dtype=float32),
#  array(0.00012592, dtype=float32),
#  array(0.00013583, dtype=float32),
#  array(0.00011847, dtype=float32),
#  array(0.0001222, dtype=float32),
#  array(0.00011675, dtype=float32),
#  array(0.00011061, dtype=float32),
#  array(0.00013639, dtype=float32),
#  array(0.00012247, dtype=float32),
#  array(0.00012155, dtype=float32),
#  array(0.00010431, dtype=float32),
#  array(0.00012494, dtype=float32),
#  array(0.000153, dtype=float32),
#  array(0.0001301, dtype=float32),
#  array(0.00012388, dtype=float32),
#  array(0.00011073, dtype=float32),
#  array(0.00011914, dtype=float32),
#  array(0.00014308, dtype=float32),
#  array(0.00011875, dtype=float32),
#  array(0.00012145, dtype=float32),
#  array(0.00010489, dtype=float32),
#  array(0.00010987, dtype=float32),
#  array(0.00011206, dtype=float32),
#  array(0.00014757, dtype=float32),
#  array(0.00012253, dtype=float32),
#  array(0.00011823, dtype=float32),
#  array(0.00013304, dtype=float32),
#  array(0.00012445, dtype=float32),
#  array(0.00015399, dtype=float32),
#  array(0.00011424, dtype=float32),
#  array(0.0001269, dtype=float32),
#  array(0.00010975, dtype=float32),
#  array(0.0001249, dtype=float32),
#  array(0.00011672, dtype=float32),
#  array(0.00011821, dtype=float32),
#  array(8.856857e-05, dtype=float32),
#  array(0.00010842, dtype=float32),
#  array(0.00011956, dtype=float32),
#  array(0.00010165, dtype=float32),
#  array(0.00011092, dtype=float32),
#  array(9.772445e-05, dtype=float32),
#  array(0.00011279, dtype=float32),
#  array(0.00010567, dtype=float32),
#  array(0.00014256, dtype=float32),
#  array(0.00011529, dtype=float32),
#  array(0.00010132, dtype=float32),
#  array(0.00012534, dtype=float32),
#  array(0.00010695, dtype=float32),
#  array(0.00012533, dtype=float32),
#  array(9.498027e-05, dtype=float32),
#  array(0.00012749, dtype=float32),
#  array(0.00012466, dtype=float32),
#  array(0.00013266, dtype=float32),
#  array(9.493505e-05, dtype=float32),
#  array(0.00010697, dtype=float32),
#  array(0.00010634, dtype=float32),
#  array(0.00011334, dtype=float32),
#  array(9.5263065e-05, dtype=float32),
#  array(0.00012477, dtype=float32),
#  array(0.00010822, dtype=float32),
#  array(0.00011269, dtype=float32),
#  array(0.00013919, dtype=float32),
#  array(0.00010771, dtype=float32),
#  array(0.00012135, dtype=float32),
#  array(0.000133, dtype=float32),
#  array(8.859405e-05, dtype=float32),
#  array(9.657057e-05, dtype=float32),
#  array(0.00012821, dtype=float32),
#  array(0.00011022, dtype=float32),
#  array(0.00011185, dtype=float32),
#  array(0.00012362, dtype=float32),
#  array(0.00012481, dtype=float32),
#  array(0.00012123, dtype=float32),
#  array(0.00011306, dtype=float32),
#  array(0.00011037, dtype=float32),
#  array(0.0001253, dtype=float32),
#  array(0.00011977, dtype=float32),
#  array(9.849221e-05, dtype=float32),
#  array(0.00012667, dtype=float32),
#  array(0.00010996, dtype=float32),
#  array(0.00011367, dtype=float32),
#  array(0.00011084, dtype=float32),
#  array(0.00013427, dtype=float32),
#  array(0.00010121, dtype=float32),
#  array(9.3923074e-05, dtype=float32),
#  array(9.406803e-05, dtype=float32),
#  array(0.00010986, dtype=float32),
#  array(9.837041e-05, dtype=float32),
#  array(0.00010615, dtype=float32),
#  array(0.0001067, dtype=float32),
#  array(0.00010162, dtype=float32),
#  array(0.00012188, dtype=float32),
#  array(0.00011631, dtype=float32),
#  array(0.00012078, dtype=float32),
#  array(0.00011518, dtype=float32),
#  array(0.00011767, dtype=float32),
#  array(0.00012513, dtype=float32),
#  array(0.00013335, dtype=float32),
#  array(0.00013057, dtype=float32),
#  array(0.00014086, dtype=float32),
#  array(0.00010281, dtype=float32),
#  array(9.785474e-05, dtype=float32),
#  array(0.00012415, dtype=float32),
#  array(9.3576404e-05, dtype=float32),
#  array(0.00011671, dtype=float32),
#  array(0.00011433, dtype=float32),
#  array(0.00010477, dtype=float32),
#  array(0.00011944, dtype=float32),
#  array(0.00014232, dtype=float32),
#  array(0.00013158, dtype=float32),
#  array(0.00010581, dtype=float32),
#  array(0.00011697, dtype=float32),
#  array(0.00011395, dtype=float32),
#  array(0.00014527, dtype=float32),
#  array(0.00010772, dtype=float32),
#  array(0.00011195, dtype=float32),
#  array(0.00011336, dtype=float32),
#  array(0.00010083, dtype=float32),
#  array(0.00012253, dtype=float32),
#  array(9.0172674e-05, dtype=float32),
#  array(0.000122, dtype=float32),
#  array(9.7784214e-05, dtype=float32),
#  array(9.625872e-05, dtype=float32),
#  array(9.8293254e-05, dtype=float32),
#  array(9.0732334e-05, dtype=float32),
#  array(0.00010904, dtype=float32),
#  array(0.00010787, dtype=float32),
#  array(0.00012273, dtype=float32),
#  array(8.7858185e-05, dtype=float32),
#  array(0.00010641, dtype=float32),
#  array(9.436294e-05, dtype=float32),
#  array(0.00011869, dtype=float32),
#  array(9.962721e-05, dtype=float32),
#  array(0.00011796, dtype=float32),
#  array(9.813103e-05, dtype=float32),
#  array(0.00011152, dtype=float32),
#  array(0.00010057, dtype=float32),
#  array(0.0001089, dtype=float32),
#  array(8.922897e-05, dtype=float32),
#  array(0.00011332, dtype=float32),
#  array(0.00011648, dtype=float32),
#  array(0.00013868, dtype=float32),
#  array(0.00010846, dtype=float32),
#  array(0.00011129, dtype=float32),
#  array(9.4500894e-05, dtype=float32),
#  array(9.155815e-05, dtype=float32),
#  array(0.00010161, dtype=float32),
#  array(0.00010961, dtype=float32),
#  array(0.0001318, dtype=float32),
#  array(0.00012885, dtype=float32),
#  array(0.00013295, dtype=float32),
#  array(0.00011919, dtype=float32),
#  array(0.00012881, dtype=float32),
#  array(0.00010008, dtype=float32),
#  array(0.00010565, dtype=float32),
#  array(0.00010975, dtype=float32),
#  array(0.00010742, dtype=float32),
#  array(0.00010805, dtype=float32),
#  array(9.623241e-05, dtype=float32),
#  array(0.00010997, dtype=float32),
#  array(0.00011874, dtype=float32),
#  array(0.00013742, dtype=float32),
#  array(8.9269626e-05, dtype=float32),
#  array(8.2348e-05, dtype=float32),
#  array(0.00010966, dtype=float32),
#  array(0.00012312, dtype=float32),
#  array(0.00012034, dtype=float32),
#  array(0.00011222, dtype=float32),
#  array(0.00011092, dtype=float32),
#  array(0.0001036, dtype=float32),
#  array(0.00012395, dtype=float32),
#  array(9.70681e-05, dtype=float32),
#  array(0.00010068, dtype=float32),
#  array(9.984274e-05, dtype=float32),
#  array(0.00010883, dtype=float32),
#  array(0.00011161, dtype=float32),
#  array(0.00010873, dtype=float32),
#  array(0.00012565, dtype=float32),
#  array(0.00011015, dtype=float32),
#  array(0.00012333, dtype=float32),
#  array(0.00012484, dtype=float32),
#  array(0.00010468, dtype=float32),
#  array(0.00013775, dtype=float32),
#  array(0.00011467, dtype=float32),
#  array(0.00011641, dtype=float32),
#  array(0.00012241, dtype=float32),
#  array(8.35143e-05, dtype=float32),
#  array(0.0001197, dtype=float32),
#  array(0.00010882, dtype=float32),
#  array(0.0001135, dtype=float32),
#  array(0.00010003, dtype=float32),
#  array(0.00010562, dtype=float32),
#  array(0.00010698, dtype=float32),
#  array(0.00010661, dtype=float32),
#  array(8.5390544e-05, dtype=float32),
#  array(0.00011194, dtype=float32),
#  array(9.4101306e-05, dtype=float32),
#  array(8.5915184e-05, dtype=float32),
#  array(0.00011073, dtype=float32),
#  array(0.00011588, dtype=float32),
#  array(0.00010076, dtype=float32),
#  array(0.00011558, dtype=float32),
#  array(0.00011013, dtype=float32),
#  array(0.00010259, dtype=float32),
#  array(0.00010883, dtype=float32),
#  array(9.6750286e-05, dtype=float32),
#  array(9.657543e-05, dtype=float32),
#  array(8.7733075e-05, dtype=float32),
#  array(7.947394e-05, dtype=float32),
#  array(8.0569014e-05, dtype=float32),
#  array(0.00012034, dtype=float32),
#  array(9.31824e-05, dtype=float32),
#  array(0.00010656, dtype=float32),
#  array(0.00014412, dtype=float32),
#  array(0.00010357, dtype=float32),
#  array(0.00010241, dtype=float32),
#  array(0.00010521, dtype=float32),
#  array(8.205791e-05, dtype=float32),
#  array(0.00010457, dtype=float32),
#  array(0.00011252, dtype=float32),
#  array(0.00015426, dtype=float32),
#  array(0.00011151, dtype=float32),
#  array(9.6873475e-05, dtype=float32),
#  array(0.00011028, dtype=float32),
#  array(9.914563e-05, dtype=float32),
#  array(0.00013256, dtype=float32),
#  array(9.569723e-05, dtype=float32),
#  array(0.00012444, dtype=float32),
#  array(0.00010738, dtype=float32),
#  array(0.00010545, dtype=float32),
#  array(0.00011875, dtype=float32),
#  array(0.00011447, dtype=float32),
#  array(0.00012618, dtype=float32),
#  array(9.0969435e-05, dtype=float32),
#  array(9.391837e-05, dtype=float32),
#  array(0.00012184, dtype=float32),
#  array(9.659139e-05, dtype=float32),
#  array(9.736516e-05, dtype=float32),
#  array(9.681539e-05, dtype=float32),
#  array(9.951799e-05, dtype=float32),
#  array(0.00011801, dtype=float32),
#  array(7.5783355e-05, dtype=float32),
#  array(0.00011839, dtype=float32),
#  array(0.00011362, dtype=float32),
#  array(9.871838e-05, dtype=float32),
#  array(0.00012181, dtype=float32),
#  array(0.00010719, dtype=float32),
#  array(9.750163e-05, dtype=float32),
#  array(9.636217e-05, dtype=float32),
#  array(0.00010279, dtype=float32),
#  array(8.753023e-05, dtype=float32),
#  array(0.00010932, dtype=float32),
#  array(9.8158824e-05, dtype=float32),
#  array(0.00010734, dtype=float32),
#  array(9.874112e-05, dtype=float32),
#  array(0.00012128, dtype=float32),
#  array(0.00010658, dtype=float32),
#  array(0.0001221, dtype=float32),
#  array(0.00010597, dtype=float32),
#  array(9.436208e-05, dtype=float32),
#  array(9.7346274e-05, dtype=float32),
#  array(0.00010373, dtype=float32),
#  array(9.4155985e-05, dtype=float32),
#  array(0.000109, dtype=float32),
#  array(0.0001164, dtype=float32),
#  array(0.00010233, dtype=float32),
#  array(8.954041e-05, dtype=float32),
#  array(9.6646865e-05, dtype=float32),
#  array(0.00011729, dtype=float32),
#  array(0.00011316, dtype=float32),
#  array(8.840763e-05, dtype=float32),
#  array(8.939621e-05, dtype=float32),
#  array(9.614186e-05, dtype=float32),
#  array(9.3936185e-05, dtype=float32),
#  array(0.00012245, dtype=float32),
#  array(9.446993e-05, dtype=float32),
#  array(0.00012084, dtype=float32),
#  array(8.901948e-05, dtype=float32),
#  array(0.00010438, dtype=float32),
#  array(0.00010457, dtype=float32),
#  array(0.00010751, dtype=float32),
#  array(8.5026186e-05, dtype=float32),
#  array(9.492459e-05, dtype=float32),
#  array(7.640656e-05, dtype=float32),
#  array(0.00010946, dtype=float32),
#  array(0.00010792, dtype=float32),
#  array(9.798133e-05, dtype=float32),
#  array(8.271994e-05, dtype=float32),
#  array(8.7227505e-05, dtype=float32),
#  array(0.00010487, dtype=float32),
#  array(8.3564504e-05, dtype=float32),
#  array(0.00012017, dtype=float32),
#  array(9.839781e-05, dtype=float32),
#  array(9.485114e-05, dtype=float32),
#  array(8.931663e-05, dtype=float32),
#  array(0.00010379, dtype=float32),
#  array(0.00010786, dtype=float32),
#  array(8.634971e-05, dtype=float32),
#  array(0.00010263, dtype=float32),
#  array(0.00011146, dtype=float32),
#  array(0.00010254, dtype=float32),
#  array(0.00010334, dtype=float32),
#  array(8.6224245e-05, dtype=float32),
#  array(9.965134e-05, dtype=float32),
#  array(0.0001116, dtype=float32),
#  array(9.991385e-05, dtype=float32),
#  array(0.00010327, dtype=float32),
#  array(9.361796e-05, dtype=float32),
#  array(0.00010002, dtype=float32),
#  array(0.00014178, dtype=float32),
#  array(0.00010184, dtype=float32),
#  array(0.00011291, dtype=float32),
#  array(8.628399e-05, dtype=float32),
#  array(0.00010184, dtype=float32),
#  array(0.00011451, dtype=float32),
#  array(9.324623e-05, dtype=float32),
#  array(0.00010621, dtype=float32),
#  array(0.00010556, dtype=float32),
#  array(9.589636e-05, dtype=float32),
#  array(0.00011453, dtype=float32),
#  array(8.51675e-05, dtype=float32),
#  array(9.0312526e-05, dtype=float32),
#  array(0.00010269, dtype=float32),
#  array(9.16305e-05, dtype=float32),
#  array(0.00011649, dtype=float32),
#  array(8.428005e-05, dtype=float32),
#  array(9.958031e-05, dtype=float32),
#  array(9.306161e-05, dtype=float32),
#  array(9.709989e-05, dtype=float32),
#  array(9.6151954e-05, dtype=float32),
#  array(0.00010719, dtype=float32),
#  array(0.00010088, dtype=float32),
#  array(0.00010227, dtype=float32),
#  array(8.929533e-05, dtype=float32),
#  array(0.00011344, dtype=float32),
#  array(0.00010296, dtype=float32),
#  array(0.00010259, dtype=float32),
#  array(0.00010645, dtype=float32),
#  array(9.372782e-05, dtype=float32),
#  array(0.00010496, dtype=float32),
#  array(8.8541055e-05, dtype=float32),
#  array(8.2971295e-05, dtype=float32),
#  array(0.00011015, dtype=float32),
#  array(9.642381e-05, dtype=float32),
#  array(0.00010659, dtype=float32),
#  array(9.8019016e-05, dtype=float32),
#  array(9.300762e-05, dtype=float32),
#  array(8.406839e-05, dtype=float32),
#  array(0.00010831, dtype=float32),
#  array(8.8833425e-05, dtype=float32),
#  array(0.00010753, dtype=float32),
#  array(9.3020855e-05, dtype=float32),
#  array(9.79181e-05, dtype=float32),
#  array(9.633563e-05, dtype=float32),
#  array(9.663712e-05, dtype=float32),
#  array(0.00011105, dtype=float32),
#  array(0.00010109, dtype=float32),
#  array(9.336534e-05, dtype=float32),
#  array(8.588759e-05, dtype=float32),
#  array(9.470065e-05, dtype=float32),
#  array(0.00010414, dtype=float32),
#  array(0.00010606, dtype=float32),
#  array(9.480692e-05, dtype=float32),
#  array(0.0001016, dtype=float32),
#  array(0.00011173, dtype=float32),
#  array(0.00011521, dtype=float32),
#  array(0.00011913, dtype=float32),
#  array(0.00011265, dtype=float32),
#  array(9.392529e-05, dtype=float32),
#  array(0.00012076, dtype=float32),
#  array(9.898162e-05, dtype=float32),
#  array(9.3708404e-05, dtype=float32),
#  array(0.00010685, dtype=float32),
#  array(9.6914235e-05, dtype=float32),
#  array(8.7565786e-05, dtype=float32),
#  array(0.00010693, dtype=float32),
#  array(0.0001212, dtype=float32),
#  array(8.488906e-05, dtype=float32),
#  array(0.00010802, dtype=float32),
#  array(0.0001209, dtype=float32),
#  array(9.596074e-05, dtype=float32),
#  array(0.00010149, dtype=float32),
#  array(0.00010153, dtype=float32),
#  array(0.00010129, dtype=float32),
#  array(0.00010182, dtype=float32),
#  array(0.00011234, dtype=float32),
#  array(0.00010351, dtype=float32),
#  array(9.647792e-05, dtype=float32),
#  array(9.588667e-05, dtype=float32),
#  array(0.00011503, dtype=float32),
#  array(0.00010805, dtype=float32),
#  array(0.00010272, dtype=float32),
#  array(8.491571e-05, dtype=float32),
#  array(0.00011921, dtype=float32),
#  array(0.00010231, dtype=float32),
#  array(0.00010281, dtype=float32),
#  array(9.841472e-05, dtype=float32),
#  array(8.6625914e-05, dtype=float32),
#  array(9.9184035e-05, dtype=float32),
#  array(9.721364e-05, dtype=float32),
#  array(0.00010078, dtype=float32),
#  array(9.649976e-05, dtype=float32),
#  array(8.8324785e-05, dtype=float32),
#  array(0.00010295, dtype=float32),
#  array(9.5880016e-05, dtype=float32),
#  array(0.0001071, dtype=float32),
#  array(9.468148e-05, dtype=float32),
#  array(9.431726e-05, dtype=float32),
#  array(9.593486e-05, dtype=float32),
#  array(9.3791365e-05, dtype=float32),
#  array(8.691334e-05, dtype=float32),
#  array(9.56448e-05, dtype=float32),
#  array(8.753528e-05, dtype=float32),
#  array(0.00010037, dtype=float32),
#  array(9.950166e-05, dtype=float32),
#  array(9.599135e-05, dtype=float32),
#  array(0.00012224, dtype=float32),
#  array(0.0001035, dtype=float32),
#  array(0.00010057, dtype=float32),
#  array(0.00011614, dtype=float32),
#  array(9.415739e-05, dtype=float32),
#  array(0.00010836, dtype=float32),
#  array(8.654826e-05, dtype=float32),
#  array(7.9655336e-05, dtype=float32),
#  array(9.514486e-05, dtype=float32),
#  array(8.695764e-05, dtype=float32),
#  array(0.00010221, dtype=float32),
#  array(9.4337054e-05, dtype=float32),
#  array(8.569591e-05, dtype=float32),
#  array(9.695999e-05, dtype=float32),
#  array(9.9400306e-05, dtype=float32),
#  array(0.00011298, dtype=float32),
#  array(9.6490345e-05, dtype=float32),
#  array(9.920345e-05, dtype=float32),
#  array(9.730211e-05, dtype=float32),
#  array(0.00012505, dtype=float32),
#  array(0.00011103, dtype=float32),
#  array(0.00013681, dtype=float32),
#  array(9.241255e-05, dtype=float32),
#  array(9.109856e-05, dtype=float32),
#  array(9.525857e-05, dtype=float32),
#  array(0.00010455, dtype=float32),
#  array(9.039403e-05, dtype=float32),
#  array(0.00011284, dtype=float32),
#  array(0.00012469, dtype=float32),
#  array(8.5288586e-05, dtype=float32),
#  array(8.786146e-05, dtype=float32),
#  array(7.910385e-05, dtype=float32),
#  array(0.00012074, dtype=float32),
#  array(9.528523e-05, dtype=float32),
#  array(7.367671e-05, dtype=float32),
#  array(0.00010656, dtype=float32),
#  array(0.00010721, dtype=float32),
#  array(9.796153e-05, dtype=float32),
#  array(9.144542e-05, dtype=float32),
#  array(0.00011892, dtype=float32),
#  array(7.683439e-05, dtype=float32),
#  array(0.00011018, dtype=float32),
#  array(8.392027e-05, dtype=float32),
#  array(0.00010174, dtype=float32),
#  array(0.00010071, dtype=float32),
#  array(8.608319e-05, dtype=float32),
#  array(9.597353e-05, dtype=float32),
#  array(9.9788136e-05, dtype=float32),
#  array(0.00010115, dtype=float32),
#  array(0.0001072, dtype=float32),
#  array(9.4510484e-05, dtype=float32),
#  array(8.8116736e-05, dtype=float32),
#  array(9.7691736e-05, dtype=float32),
#  array(8.736747e-05, dtype=float32),
#  array(9.08639e-05, dtype=float32),
#  array(8.773255e-05, dtype=float32),
#  array(7.965799e-05, dtype=float32),
#  array(9.601173e-05, dtype=float32),
#  array(9.037736e-05, dtype=float32),
#  array(0.00010942, dtype=float32),
#  array(8.973275e-05, dtype=float32),
#  array(0.0001038, dtype=float32),
#  array(0.00011129, dtype=float32),
#  array(9.098656e-05, dtype=float32),
#  array(9.254436e-05, dtype=float32),
#  array(8.7781096e-05, dtype=float32),
#  array(9.294602e-05, dtype=float32),
#  array(0.00010918, dtype=float32),
#  array(0.00010484, dtype=float32),
#  array(0.00010485, dtype=float32),
#  array(0.00011532, dtype=float32),
#  array(0.00011949, dtype=float32),
#  array(9.041397e-05, dtype=float32),
#  array(0.00011041, dtype=float32),
#  array(0.00011282, dtype=float32),
#  array(9.49301e-05, dtype=float32),
#  array(9.011492e-05, dtype=float32),
#  array(0.00013307, dtype=float32),
#  array(9.63628e-05, dtype=float32),
#  array(0.00011419, dtype=float32),
#  array(0.00013678, dtype=float32),
#  array(0.00011212, dtype=float32),
#  array(0.00011721, dtype=float32),
#  array(9.4546675e-05, dtype=float32),
#  array(0.00010747, dtype=float32),
#  array(0.00011407, dtype=float32),
#  array(9.526881e-05, dtype=float32),
#  array(8.983481e-05, dtype=float32),
#  array(0.00011348, dtype=float32),
#  array(0.00010825, dtype=float32),
#  array(9.743345e-05, dtype=float32),
#  array(0.00010002, dtype=float32),
#  array(0.00010498, dtype=float32),
#  array(9.591658e-05, dtype=float32),
#  array(9.16141e-05, dtype=float32),
#  array(0.00012826, dtype=float32),
#  array(0.00011032, dtype=float32),
#  array(9.448566e-05, dtype=float32),
#  array(9.2696144e-05, dtype=float32),
#  array(9.111234e-05, dtype=float32),
#  array(0.00011173, dtype=float32),
#  array(0.00011067, dtype=float32),
#  array(9.212037e-05, dtype=float32),
#  array(9.954376e-05, dtype=float32),
#  array(9.8432465e-05, dtype=float32),
#  array(9.147497e-05, dtype=float32),
#  array(8.443113e-05, dtype=float32),
#  array(0.00011708, dtype=float32),
#  array(0.00010077, dtype=float32),
#  array(0.00010122, dtype=float32),
#  array(0.00010708, dtype=float32),
#  array(0.00010633, dtype=float32),
#  array(8.4694075e-05, dtype=float32),
#  array(9.528463e-05, dtype=float32),
#  array(8.810352e-05, dtype=float32),
#  array(7.96953e-05, dtype=float32),
#  array(0.00011912, dtype=float32),
#  array(7.891061e-05, dtype=float32),
#  array(7.256052e-05, dtype=float32),
#  array(0.00010004, dtype=float32),
#  array(0.00010413, dtype=float32),
#  array(8.165362e-05, dtype=float32),
#  array(9.394529e-05, dtype=float32),
#  array(0.00012449, dtype=float32),
#  array(0.00012196, dtype=float32),
#  array(0.00010235, dtype=float32),
#  array(9.67858e-05, dtype=float32),
#  array(0.00010248, dtype=float32),
#  array(9.7515076e-05, dtype=float32),
#  array(0.00010407, dtype=float32),
#  array(0.00010271, dtype=float32),
#  array(9.684433e-05, dtype=float32),
#  array(0.00010177, dtype=float32),
#  array(8.6266555e-05, dtype=float32),
#  array(0.00010688, dtype=float32),
#  array(9.8174125e-05, dtype=float32),
#  array(9.704687e-05, dtype=float32),
#  array(9.1166534e-05, dtype=float32),
#  array(9.404616e-05, dtype=float32),
#  array(0.00010353, dtype=float32),
#  array(9.627623e-05, dtype=float32),
#  array(9.774444e-05, dtype=float32),
#  array(0.00010184, dtype=float32),
#  array(9.864803e-05, dtype=float32),
#  array(7.7481454e-05, dtype=float32),
#  array(0.00010791, dtype=float32),
#  array(0.000107, dtype=float32),
#  array(9.026453e-05, dtype=float32),
#  array(9.626342e-05, dtype=float32),
#  array(9.509492e-05, dtype=float32),
#  array(0.00010714, dtype=float32),
#  array(0.00010983, dtype=float32),
#  array(8.581413e-05, dtype=float32),
#  array(8.440419e-05, dtype=float32),
#  array(0.00010825, dtype=float32),
#  array(7.319421e-05, dtype=float32),
#  array(7.857138e-05, dtype=float32),
#  array(8.753813e-05, dtype=float32),
#  array(0.00010241, dtype=float32),
#  array(8.97899e-05, dtype=float32),
#  array(0.00010161, dtype=float32),
#  array(8.389935e-05, dtype=float32),
#  array(0.00011736, dtype=float32),
#  array(8.962407e-05, dtype=float32),
#  array(9.7329066e-05, dtype=float32),
#  array(9.8592136e-05, dtype=float32),
#  array(0.00010356, dtype=float32),
#  array(8.594667e-05, dtype=float32),
#  array(0.00012449, dtype=float32),
#  array(9.8297445e-05, dtype=float32),
#  array(0.00010321, dtype=float32),
#  array(0.00011736, dtype=float32),
#  array(0.00011191, dtype=float32),
#  array(0.00010909, dtype=float32),
#  array(0.00011305, dtype=float32),
#  array(0.00012383, dtype=float32),
#  array(0.00012171, dtype=float32),
#  array(0.00011009, dtype=float32),
#  array(0.00010837, dtype=float32),
#  array(0.00011458, dtype=float32),
#  array(0.00011931, dtype=float32),
#  array(0.00012676, dtype=float32),
#  array(9.208478e-05, dtype=float32),
#  array(9.5370444e-05, dtype=float32),
#  array(0.00010277, dtype=float32),
#  array(0.00010417, dtype=float32),
#  array(9.028062e-05, dtype=float32),
#  array(9.4026014e-05, dtype=float32),
#  array(9.725524e-05, dtype=float32),
#  array(0.00011822, dtype=float32),
#  array(9.698275e-05, dtype=float32),
#  array(7.983735e-05, dtype=float32),
#  array(0.00012362, dtype=float32),
#  array(0.0001102, dtype=float32),
#  array(9.1607464e-05, dtype=float32),
#  array(9.101353e-05, dtype=float32),
#  array(0.00010086, dtype=float32),
#  array(0.00011062, dtype=float32),
#  array(0.0001273, dtype=float32),
#  array(9.942357e-05, dtype=float32),
#  array(0.00010741, dtype=float32),
#  array(0.00011241, dtype=float32),
#  array(9.219115e-05, dtype=float32),
#  array(9.339646e-05, dtype=float32),
#  array(9.5732554e-05, dtype=float32),
#  array(0.00011722, dtype=float32),
#  array(0.00010478, dtype=float32),
#  array(8.636786e-05, dtype=float32),
#  array(0.0001237, dtype=float32),
#  array(9.592999e-05, dtype=float32),
#  array(9.739147e-05, dtype=float32),
#  array(0.00010247, dtype=float32),
#  array(9.4482835e-05, dtype=float32),
#  array(0.00010108, dtype=float32),
#  array(9.249231e-05, dtype=float32),
#  array(0.00010181, dtype=float32),
#  array(9.131867e-05, dtype=float32),
#  array(8.5485895e-05, dtype=float32),
#  array(0.00010754, dtype=float32),
#  array(8.179851e-05, dtype=float32),
#  array(9.300913e-05, dtype=float32),
#  array(8.337284e-05, dtype=float32),
#  array(8.175368e-05, dtype=float32),
#  array(0.00010161, dtype=float32),
#  array(0.00010656, dtype=float32),
#  array(7.714987e-05, dtype=float32),
#  array(8.953932e-05, dtype=float32),
#  array(0.00011837, dtype=float32),
#  array(0.00010524, dtype=float32),
#  array(8.346701e-05, dtype=float32),
#  array(0.00011878, dtype=float32),
#  array(9.1471185e-05, dtype=float32),
#  array(8.727572e-05, dtype=float32),
#  array(0.00010529, dtype=float32),
#  array(0.00010034, dtype=float32),
#  array(9.149909e-05, dtype=float32),
#  array(8.79811e-05, dtype=float32),
#  array(9.852876e-05, dtype=float32),
#  array(8.317273e-05, dtype=float32),
#  array(9.4814066e-05, dtype=float32),
#  array(0.00011644, dtype=float32),
#  array(9.062334e-05, dtype=float32),
#  array(8.5129635e-05, dtype=float32),
#  array(9.897823e-05, dtype=float32),
#  array(0.0001033, dtype=float32),
#  array(9.2763854e-05, dtype=float32),
#  array(9.9677505e-05, dtype=float32),
#  array(9.336248e-05, dtype=float32),
#  array(0.00010626, dtype=float32),
#  array(0.0001065, dtype=float32),
#  array(8.7085224e-05, dtype=float32),
#  array(9.50882e-05, dtype=float32),
#  array(0.00011009, dtype=float32),
#  array(0.00011373, dtype=float32),
#  array(9.109825e-05, dtype=float32),
#  array(9.753763e-05, dtype=float32),
#  array(9.708814e-05, dtype=float32),
#  array(0.00011408, dtype=float32),
#  array(0.0001051, dtype=float32),
#  array(0.00010884, dtype=float32),
#  array(9.9432524e-05, dtype=float32),
#  array(9.624349e-05, dtype=float32),
#  array(0.0001127, dtype=float32),
#  array(7.314141e-05, dtype=float32),
#  array(0.00010397, dtype=float32),
#  array(0.00011312, dtype=float32),
#  array(0.00011044, dtype=float32),
#  array(0.00010485, dtype=float32),
#  array(0.00011319, dtype=float32),
#  array(8.2477985e-05, dtype=float32),
#  array(8.809556e-05, dtype=float32),
#  array(0.00010506, dtype=float32),
#  array(0.00010422, dtype=float32),
#  array(8.509242e-05, dtype=float32),
#  array(0.00010084, dtype=float32),
#  array(8.520658e-05, dtype=float32),
#  array(9.2910734e-05, dtype=float32),
#  array(0.0001171, dtype=float32),
#  array(0.00010061, dtype=float32),
#  array(0.00010091, dtype=float32),
#  array(0.00010537, dtype=float32),
#  array(8.281664e-05, dtype=float32),
#  array(0.00010812, dtype=float32),
#  array(8.0360725e-05, dtype=float32),
#  array(8.8237e-05, dtype=float32),
#  array(8.277627e-05, dtype=float32),
#  array(0.00010694, dtype=float32),
#  array(0.00012579, dtype=float32),
#  array(0.0001049, dtype=float32),
#  array(9.794466e-05, dtype=float32),
#  array(0.00010981, dtype=float32),
#  array(8.580934e-05, dtype=float32),
#  array(0.00010745, dtype=float32),
#  array(0.00010076, dtype=float32),
#  array(9.0215646e-05, dtype=float32),
#  array(9.151262e-05, dtype=float32),
#  array(0.00010442, dtype=float32),
#  array(0.00010907, dtype=float32),
#  array(0.00010137, dtype=float32),
#  array(0.00012816, dtype=float32),
#  array(0.00010259, dtype=float32),
#  array(9.590493e-05, dtype=float32),
#  array(8.679853e-05, dtype=float32),
#  array(0.00011313, dtype=float32),
#  array(9.217832e-05, dtype=float32),
#  array(9.747771e-05, dtype=float32),
#  array(8.723247e-05, dtype=float32),
#  array(8.085966e-05, dtype=float32),
#  array(9.312722e-05, dtype=float32),
#  array(7.8916695e-05, dtype=float32),
#  array(0.00010238, dtype=float32),
#  array(0.00010087, dtype=float32),
#  array(9.976746e-05, dtype=float32),
#  array(9.71841e-05, dtype=float32),
#  array(0.0001006, dtype=float32),
#  array(8.887029e-05, dtype=float32),
#  array(9.487038e-05, dtype=float32),
#  array(9.4051575e-05, dtype=float32),
#  array(9.716516e-05, dtype=float32),
#  array(8.337326e-05, dtype=float32),
#  array(9.360038e-05, dtype=float32),
#  array(0.00011317, dtype=float32),
#  array(0.00010854, dtype=float32),
#  array(9.414022e-05, dtype=float32),
#  array(0.00010772, dtype=float32),
#  array(0.00010061, dtype=float32),
#  array(9.368321e-05, dtype=float32),
#  array(8.9968235e-05, dtype=float32),
#  array(0.0001083, dtype=float32),
#  array(9.9881814e-05, dtype=float32),
#  array(9.5122545e-05, dtype=float32),
#  array(9.3795636e-05, dtype=float32),
#  array(9.985264e-05, dtype=float32),
#  array(0.00010017, dtype=float32),
#  array(0.00010988, dtype=float32),
#  array(0.00010493, dtype=float32),
#  array(8.655617e-05, dtype=float32),
#  array(8.8450746e-05, dtype=float32),
#  array(9.1912996e-05, dtype=float32),
#  array(0.0001124, dtype=float32),
#  array(9.426386e-05, dtype=float32),
#  array(0.00011185, dtype=float32),
#  array(8.548758e-05, dtype=float32),
#  array(8.131896e-05, dtype=float32),
#  array(9.7182696e-05, dtype=float32),
#  array(0.00010129, dtype=float32),
#  array(0.0001073, dtype=float32),
#  array(9.155413e-05, dtype=float32),
#  array(0.00012639, dtype=float32),
#  array(7.759401e-05, dtype=float32),
#  array(8.5048494e-05, dtype=float32),
#  array(8.922817e-05, dtype=float32),
#  array(8.408527e-05, dtype=float32),
#  array(9.612826e-05, dtype=float32),
#  array(9.2611815e-05, dtype=float32),
#  array(9.443399e-05, dtype=float32),
#  array(0.00011906, dtype=float32),
#  array(9.846993e-05, dtype=float32),
#  array(0.00012073, dtype=float32),
#  array(0.00011796, dtype=float32),
#  array(9.392037e-05, dtype=float32),
#  array(0.00010036, dtype=float32),
#  array(8.9357694e-05, dtype=float32),
#  array(9.62903e-05, dtype=float32),
#  array(9.1517635e-05, dtype=float32),
#  array(0.00010786, dtype=float32),
#  array(0.00010667, dtype=float32),
#  array(0.00010099, dtype=float32),
#  array(9.2344744e-05, dtype=float32),
#  array(8.624686e-05, dtype=float32),
#  array(8.580905e-05, dtype=float32),
#  array(7.858132e-05, dtype=float32),
#  array(8.31224e-05, dtype=float32),
#  array(9.6198695e-05, dtype=float32),
#  array(0.00011632, dtype=float32),
#  array(0.00010937, dtype=float32),
#  array(8.904109e-05, dtype=float32),
#  array(0.00012319, dtype=float32),
#  array(0.00011134, dtype=float32),
#  array(9.42092e-05, dtype=float32),
#  array(0.00010314, dtype=float32),
#  array(0.0001236, dtype=float32),
#  array(9.715195e-05, dtype=float32),
#  array(9.7014665e-05, dtype=float32),
#  array(0.0001058, dtype=float32),
#  array(7.510459e-05, dtype=float32),
#  array(8.606694e-05, dtype=float32),
#  array(7.542576e-05, dtype=float32),
#  array(8.682004e-05, dtype=float32),
#  array(9.690202e-05, dtype=float32),
#  array(0.00011472, dtype=float32),
#  array(9.152825e-05, dtype=float32),
#  array(8.084769e-05, dtype=float32),
#  array(7.07387e-05, dtype=float32),
#  array(9.095727e-05, dtype=float32),
#  array(0.00010091, dtype=float32),
#  array(0.0001021, dtype=float32),
#  array(0.0001129, dtype=float32),
#  array(8.370294e-05, dtype=float32),
#  array(9.8249104e-05, dtype=float32),
#  array(0.00011915, dtype=float32),
#  array(0.00010312, dtype=float32),
#  array(0.00010658, dtype=float32),
#  array(8.599933e-05, dtype=float32),
#  array(9.145867e-05, dtype=float32),
#  array(0.00010329, dtype=float32),
#  array(9.761273e-05, dtype=float32),
#  array(9.924626e-05, dtype=float32),
#  array(0.00010247, dtype=float32),
#  array(0.00010303, dtype=float32),
#  array(8.752427e-05, dtype=float32),
#  array(9.314779e-05, dtype=float32),
#  array(9.37563e-05, dtype=float32),
#  array(9.4886345e-05, dtype=float32),
#  ...]

# %%
trainer.evaluate(graph_ani_test_loader)
# Out:
# 6.451507583219832e-08

# %%
node_input_dim = graph_train.dataset[0].x.shape[1]
edge_input_dim = graph_train.dataset[0].edge_attr.shape[1]

# %%
node_hidden_dim = 128
edge_hidden_dim = 128

net = GraphNet(node_input_dim, edge_input_dim, node_hidden_dim, edge_hidden_dim).to(device)

# %%
graph_train_list = [graph_train_1, graph_train_2, graph_train_3, graph_train_4]

# %%
def check_dataloader_device(dataloader):
    loop = 0
    for batch_data in dataloader:
        # Print the device of each tensor in the batch
        print("Node features device:", batch_data.x.device)
        print("Edge features device:", batch_data.edge_attr.device)
        print("Edge index device:", batch_data.edge_index.device)
        print("Target tensor device:", batch_data.y.device)
        loop += 1
        if loop >= 3:
            return 

# Assuming graph_train_loader is your DataLoader
check_dataloader_device(graph_train)
# Out:
# Node features device: cuda:0
# Edge features device: cuda:0
# Edge index device: cuda:0
# Target tensor device: cuda:0
# Node features device: cuda:0
# Edge features device: cuda:0
# Edge index device: cuda:0
# Target tensor device: cuda:0
# Node features device: cuda:0
# Edge features device: cuda:0
# Edge index device: cuda:0
# Target tensor device: cuda:0

# %%
# train 
learning_rate = 1e-3
n_epoch = 50
batch_size = 16384
l2 = 1e-4

trainer = GNNTrainer(net, batch_size, learning_rate, n_epoch, l2)
trainer.train(graph_train, graph_val)
# Out:
# GraphNet - Number of parameters: 84609
# 100%|██████████| 50/50 [1:01:12<00:00, 73.45s/it]
# [array(0.0029157, dtype=float32),
#  array(0.00384375, dtype=float32),
#  array(0.00260933, dtype=float32),
#  array(0.00277813, dtype=float32),
#  array(0.00259892, dtype=float32),
#  array(0.00237202, dtype=float32),
#  array(0.00231348, dtype=float32),
#  array(0.00252627, dtype=float32),
#  array(0.00249178, dtype=float32),
#  array(0.0022276, dtype=float32),
#  array(0.00230725, dtype=float32),
#  array(0.00250707, dtype=float32),
#  array(0.00244033, dtype=float32),
#  array(0.00233226, dtype=float32),
#  array(0.00229282, dtype=float32),
#  array(0.0022483, dtype=float32),
#  array(0.00219979, dtype=float32),
#  array(0.00250606, dtype=float32),
#  array(0.0022709, dtype=float32),
#  array(0.00230809, dtype=float32),
#  array(0.00240601, dtype=float32),
#  array(0.00225652, dtype=float32),
#  array(0.00223784, dtype=float32),
#  array(0.00230702, dtype=float32),
#  array(0.0023187, dtype=float32),
#  array(0.00229485, dtype=float32),
#  array(0.00239114, dtype=float32),
#  array(0.00236081, dtype=float32),
#  array(0.0022558, dtype=float32),
#  array(0.00220794, dtype=float32),
#  array(0.00233195, dtype=float32),
#  array(0.00229913, dtype=float32),
#  array(0.00224547, dtype=float32),
#  array(0.0022262, dtype=float32),
#  array(0.00212069, dtype=float32),
#  array(0.00220454, dtype=float32),
#  array(0.00225677, dtype=float32),
#  array(0.002182, dtype=float32),
#  array(0.002296, dtype=float32),
#  array(0.00248465, dtype=float32),
#  array(0.0023861, dtype=float32),
#  array(0.00243018, dtype=float32),
#  array(0.00233333, dtype=float32),
#  array(0.00234478, dtype=float32),
#  array(0.00210049, dtype=float32),
#  array(0.00228679, dtype=float32),
#  array(0.00228512, dtype=float32),
#  array(0.00220943, dtype=float32),
#  array(0.00233413, dtype=float32),
#  array(0.00239775, dtype=float32),
#  array(0.0023056, dtype=float32),
#  array(0.00232016, dtype=float32),
#  array(0.00221991, dtype=float32),
#  array(0.00245089, dtype=float32),
#  array(0.0023687, dtype=float32),
#  array(0.00241052, dtype=float32),
#  array(0.00225285, dtype=float32),
#  array(0.00231477, dtype=float32),
#  array(0.00217126, dtype=float32),
#  array(0.00236482, dtype=float32),
#  array(0.00231091, dtype=float32),
#  array(0.00206476, dtype=float32),
#  array(0.00231885, dtype=float32),
#  array(0.00224267, dtype=float32),
#  array(0.00246137, dtype=float32),
#  array(0.00228436, dtype=float32),
#  array(0.0023838, dtype=float32),
#  array(0.0023168, dtype=float32),
#  array(0.00228083, dtype=float32),
#  array(0.00226745, dtype=float32),
#  array(0.00229441, dtype=float32),
#  array(0.00233819, dtype=float32),
#  array(0.00237353, dtype=float32),
#  array(0.00233366, dtype=float32),
#  array(0.00225172, dtype=float32),
#  array(0.0022746, dtype=float32),
#  array(0.00243242, dtype=float32),
#  array(0.00223838, dtype=float32),
#  array(0.00223306, dtype=float32),
#  array(0.00214978, dtype=float32),
#  array(0.00231638, dtype=float32),
#  array(0.0021993, dtype=float32),
#  array(0.00238747, dtype=float32),
#  array(0.00224725, dtype=float32),
#  array(0.00228195, dtype=float32),
#  array(0.00243643, dtype=float32),
#  array(0.00224036, dtype=float32),
#  array(0.00226674, dtype=float32),
#  array(0.00223588, dtype=float32),
#  array(0.00220184, dtype=float32),
#  array(0.00233264, dtype=float32),
#  array(0.002162, dtype=float32),
#  array(0.00222202, dtype=float32),
#  array(0.00222854, dtype=float32),
#  array(0.00223602, dtype=float32),
#  array(0.00241511, dtype=float32),
#  array(0.00217719, dtype=float32),
#  array(0.00220782, dtype=float32),
#  array(0.00215039, dtype=float32),
#  array(0.00240463, dtype=float32),
#  array(0.00219399, dtype=float32),
#  array(0.00220933, dtype=float32),
#  array(0.00243951, dtype=float32),
#  array(0.00222518, dtype=float32),
#  array(0.00231334, dtype=float32),
#  array(0.00244324, dtype=float32),
#  array(0.00241987, dtype=float32),
#  array(0.00231732, dtype=float32),
#  array(0.0023212, dtype=float32),
#  array(0.00230418, dtype=float32),
#  array(0.00229611, dtype=float32),
#  array(0.00226659, dtype=float32),
#  array(0.00236134, dtype=float32),
#  array(0.00239391, dtype=float32),
#  array(0.00241389, dtype=float32),
#  array(0.00238113, dtype=float32),
#  array(0.00223763, dtype=float32),
#  array(0.00218539, dtype=float32),
#  array(0.00254591, dtype=float32),
#  array(0.00230998, dtype=float32),
#  array(0.0022563, dtype=float32),
#  array(0.00233017, dtype=float32),
#  array(0.00227708, dtype=float32),
#  array(0.00233512, dtype=float32),
#  array(0.00208099, dtype=float32),
#  array(0.00236405, dtype=float32),
#  array(0.00223195, dtype=float32),
#  array(0.00231007, dtype=float32),
#  array(0.00218308, dtype=float32),
#  array(0.00243668, dtype=float32),
#  array(0.00223989, dtype=float32),
#  array(0.00215583, dtype=float32),
#  array(0.00241658, dtype=float32),
#  array(0.002173, dtype=float32),
#  array(0.00213255, dtype=float32),
#  array(0.00228994, dtype=float32),
#  array(0.0022858, dtype=float32),
#  array(0.00239196, dtype=float32),
#  array(0.00217418, dtype=float32),
#  array(0.00229502, dtype=float32),
#  array(0.00234917, dtype=float32),
#  array(0.00222338, dtype=float32),
#  array(0.00230758, dtype=float32),
#  array(0.00219558, dtype=float32),
#  array(0.00217552, dtype=float32),
#  array(0.00237851, dtype=float32),
#  array(0.00242744, dtype=float32),
#  array(0.00224871, dtype=float32),
#  array(0.0022171, dtype=float32),
#  array(0.00216309, dtype=float32),
#  array(0.00243052, dtype=float32),
#  array(0.00226504, dtype=float32),
#  array(0.00222186, dtype=float32),
#  array(0.00230053, dtype=float32),
#  array(0.00226547, dtype=float32),
#  array(0.00226856, dtype=float32),
#  array(0.00217039, dtype=float32),
#  array(0.00225847, dtype=float32),
#  array(0.00235814, dtype=float32),
#  array(0.00241556, dtype=float32),
#  array(0.00219232, dtype=float32),
#  array(0.002389, dtype=float32),
#  array(0.00252821, dtype=float32),
#  array(0.00244577, dtype=float32),
#  array(0.00219792, dtype=float32),
#  array(0.00231845, dtype=float32),
#  array(0.00235069, dtype=float32),
#  array(0.00240844, dtype=float32),
#  array(0.00238966, dtype=float32),
#  array(0.00247238, dtype=float32),
#  array(0.00239269, dtype=float32),
#  array(0.00244326, dtype=float32),
#  array(0.00242452, dtype=float32),
#  array(0.00236175, dtype=float32),
#  array(0.00225315, dtype=float32),
#  array(0.00230434, dtype=float32),
#  array(0.00242899, dtype=float32),
#  array(0.00236591, dtype=float32),
#  array(0.00215922, dtype=float32),
#  array(0.00240572, dtype=float32),
#  array(0.00218272, dtype=float32),
#  array(0.00230263, dtype=float32),
#  array(0.0022115, dtype=float32),
#  array(0.00231555, dtype=float32),
#  array(0.00220263, dtype=float32),
#  array(0.00238206, dtype=float32),
#  array(0.00211895, dtype=float32),
#  array(0.00225817, dtype=float32),
#  array(0.00234283, dtype=float32),
#  array(0.00233318, dtype=float32),
#  array(0.0024033, dtype=float32),
#  array(0.00212943, dtype=float32),
#  array(0.00228103, dtype=float32),
#  array(0.00229448, dtype=float32),
#  array(0.00223946, dtype=float32),
#  array(0.00246126, dtype=float32),
#  array(0.00225549, dtype=float32),
#  array(0.00234518, dtype=float32),
#  array(0.0022675, dtype=float32),
#  array(0.00228183, dtype=float32),
#  array(0.0023218, dtype=float32),
#  array(0.00235226, dtype=float32),
#  array(0.00223812, dtype=float32),
#  array(0.00245923, dtype=float32),
#  array(0.00234808, dtype=float32),
#  array(0.0022034, dtype=float32),
#  array(0.00236365, dtype=float32),
#  array(0.00239002, dtype=float32),
#  array(0.00219805, dtype=float32),
#  array(0.00224654, dtype=float32),
#  array(0.00232787, dtype=float32),
#  array(0.00222724, dtype=float32),
#  array(0.00229926, dtype=float32),
#  array(0.00224876, dtype=float32),
#  array(0.00230618, dtype=float32),
#  array(0.00220069, dtype=float32),
#  array(0.00223588, dtype=float32),
#  array(0.00211007, dtype=float32),
#  array(0.00220278, dtype=float32),
#  array(0.00232416, dtype=float32),
#  array(0.00222952, dtype=float32),
#  array(0.00215496, dtype=float32),
#  array(0.00234371, dtype=float32),
#  array(0.00221256, dtype=float32),
#  array(0.00217935, dtype=float32),
#  array(0.00225291, dtype=float32),
#  array(0.00231898, dtype=float32),
#  array(0.00223545, dtype=float32),
#  array(0.0023272, dtype=float32),
#  array(0.00224269, dtype=float32),
#  array(0.00240318, dtype=float32),
#  array(0.00227305, dtype=float32),
#  array(0.00217028, dtype=float32),
#  array(0.00237954, dtype=float32),
#  array(0.00238163, dtype=float32),
#  array(0.00231408, dtype=float32),
#  array(0.00215994, dtype=float32),
#  array(0.002232, dtype=float32),
#  array(0.00238897, dtype=float32),
#  array(0.00218914, dtype=float32),
#  array(0.00228689, dtype=float32),
#  array(0.00242113, dtype=float32),
#  array(0.00224886, dtype=float32),
#  array(0.00213114, dtype=float32),
#  array(0.00245864, dtype=float32),
#  array(0.00223881, dtype=float32),
#  array(0.00201165, dtype=float32),
#  array(0.00232743, dtype=float32),
#  array(0.00252855, dtype=float32),
#  array(0.00246312, dtype=float32),
#  array(0.00230021, dtype=float32),
#  array(0.00233603, dtype=float32),
#  array(0.00234177, dtype=float32),
#  array(0.00238121, dtype=float32),
#  array(0.00244854, dtype=float32),
#  array(0.00220967, dtype=float32),
#  array(0.00217031, dtype=float32),
#  array(0.0022864, dtype=float32),
#  array(0.00216525, dtype=float32),
#  array(0.00231492, dtype=float32),
#  array(0.00227455, dtype=float32),
#  array(0.00232717, dtype=float32),
#  array(0.00227507, dtype=float32),
#  array(0.00227014, dtype=float32),
#  array(0.00216588, dtype=float32),
#  array(0.00234935, dtype=float32),
#  array(0.00233625, dtype=float32),
#  array(0.00246893, dtype=float32),
#  array(0.00241628, dtype=float32),
#  array(0.00232756, dtype=float32),
#  array(0.00214353, dtype=float32),
#  array(0.00233882, dtype=float32),
#  array(0.00237542, dtype=float32),
#  array(0.00216014, dtype=float32),
#  array(0.00232374, dtype=float32),
#  array(0.002272, dtype=float32),
#  array(0.00233773, dtype=float32),
#  array(0.00245069, dtype=float32),
#  array(0.00247019, dtype=float32),
#  array(0.00229069, dtype=float32),
#  array(0.0022858, dtype=float32),
#  array(0.00233892, dtype=float32),
#  array(0.00228363, dtype=float32),
#  array(0.00226782, dtype=float32),
#  array(0.00228491, dtype=float32),
#  array(0.0022123, dtype=float32),
#  array(0.00228259, dtype=float32),
#  array(0.00246306, dtype=float32),
#  array(0.00232331, dtype=float32),
#  array(0.00229886, dtype=float32),
#  array(0.00230627, dtype=float32),
#  array(0.00228154, dtype=float32),
#  array(0.00240381, dtype=float32),
#  array(0.00230638, dtype=float32),
#  array(0.00233992, dtype=float32),
#  array(0.00226153, dtype=float32),
#  array(0.00226875, dtype=float32),
#  array(0.00238855, dtype=float32),
#  array(0.0022764, dtype=float32),
#  array(0.00210396, dtype=float32),
#  array(0.00229465, dtype=float32),
#  array(0.00232452, dtype=float32),
#  array(0.00241644, dtype=float32),
#  array(0.00241171, dtype=float32),
#  array(0.00225705, dtype=float32),
#  array(0.00222469, dtype=float32),
#  array(0.00224813, dtype=float32),
#  array(0.00209785, dtype=float32),
#  array(0.00221245, dtype=float32),
#  array(0.00240107, dtype=float32),
#  array(0.00240674, dtype=float32),
#  array(0.0024142, dtype=float32),
#  array(0.00236099, dtype=float32),
#  array(0.00228184, dtype=float32),
#  array(0.00217019, dtype=float32),
#  array(0.00224266, dtype=float32),
#  array(0.00230364, dtype=float32),
#  array(0.00224008, dtype=float32),
#  array(0.00213286, dtype=float32),
#  array(0.00235217, dtype=float32),
#  array(0.00235353, dtype=float32),
#  array(0.00218993, dtype=float32),
#  array(0.00212819, dtype=float32),
#  array(0.00229837, dtype=float32),
#  array(0.00244162, dtype=float32),
#  array(0.00230291, dtype=float32),
#  array(0.00232521, dtype=float32),
#  array(0.00231339, dtype=float32),
#  array(0.00221818, dtype=float32),
#  array(0.00236866, dtype=float32),
#  array(0.00214734, dtype=float32),
#  array(0.0022091, dtype=float32),
#  array(0.00234842, dtype=float32),
#  array(0.00217901, dtype=float32),
#  array(0.00240878, dtype=float32),
#  array(0.00233734, dtype=float32),
#  array(0.00224098, dtype=float32),
#  array(0.00221555, dtype=float32),
#  array(0.00230944, dtype=float32),
#  array(0.00243454, dtype=float32),
#  array(0.00223499, dtype=float32),
#  array(0.00231234, dtype=float32),
#  array(0.00248444, dtype=float32),
#  array(0.00215876, dtype=float32),
#  array(0.00217806, dtype=float32),
#  array(0.00229836, dtype=float32),
#  array(0.00222304, dtype=float32),
#  array(0.00218854, dtype=float32),
#  array(0.00214761, dtype=float32),
#  array(0.00240173, dtype=float32),
#  array(0.00233302, dtype=float32),
#  array(0.00222735, dtype=float32),
#  array(0.00224346, dtype=float32),
#  array(0.00230286, dtype=float32),
#  array(0.00223809, dtype=float32),
#  array(0.00231815, dtype=float32),
#  array(0.00231962, dtype=float32),
#  array(0.00228834, dtype=float32),
#  array(0.00230753, dtype=float32),
#  array(0.00205719, dtype=float32),
#  array(0.00218092, dtype=float32),
#  array(0.00224941, dtype=float32),
#  array(0.00232914, dtype=float32),
#  array(0.00226106, dtype=float32),
#  array(0.00237302, dtype=float32),
#  array(0.00236979, dtype=float32),
#  array(0.0024325, dtype=float32),
#  array(0.00242952, dtype=float32),
#  array(0.0023235, dtype=float32),
#  array(0.00225463, dtype=float32),
#  array(0.00221455, dtype=float32),
#  array(0.00228419, dtype=float32),
#  array(0.00220186, dtype=float32),
#  array(0.00253015, dtype=float32),
#  array(0.00209673, dtype=float32),
#  array(0.00232321, dtype=float32),
#  array(0.00218062, dtype=float32),
#  array(0.00208144, dtype=float32),
#  array(0.0022042, dtype=float32),
#  array(0.00216011, dtype=float32),
#  array(0.00249507, dtype=float32),
#  array(0.00228128, dtype=float32),
#  array(0.0024341, dtype=float32),
#  array(0.00232717, dtype=float32),
#  array(0.00216377, dtype=float32),
#  array(0.00230712, dtype=float32),
#  array(0.00229273, dtype=float32),
#  array(0.00219088, dtype=float32),
#  array(0.00234394, dtype=float32),
#  array(0.00226948, dtype=float32),
#  array(0.00242519, dtype=float32),
#  array(0.0024083, dtype=float32),
#  array(0.00242926, dtype=float32),
#  array(0.00240089, dtype=float32),
#  array(0.00224241, dtype=float32),
#  array(0.00221922, dtype=float32),
#  array(0.00229206, dtype=float32),
#  array(0.00229081, dtype=float32),
#  array(0.00231492, dtype=float32),
#  array(0.00232441, dtype=float32),
#  array(0.0023461, dtype=float32),
#  array(0.00238283, dtype=float32),
#  array(0.00242421, dtype=float32),
#  array(0.00240191, dtype=float32),
#  array(0.00233479, dtype=float32),
#  array(0.00225644, dtype=float32),
#  array(0.00235471, dtype=float32),
#  array(0.00222386, dtype=float32),
#  array(0.00226303, dtype=float32),
#  array(0.00235316, dtype=float32),
#  array(0.00246027, dtype=float32),
#  array(0.00221698, dtype=float32),
#  array(0.0022489, dtype=float32),
#  array(0.00250727, dtype=float32),
#  array(0.00233738, dtype=float32),
#  array(0.00235022, dtype=float32),
#  array(0.00227774, dtype=float32),
#  array(0.00251016, dtype=float32),
#  array(0.00235227, dtype=float32),
#  array(0.00211414, dtype=float32),
#  array(0.00232927, dtype=float32),
#  array(0.00223603, dtype=float32),
#  array(0.00212939, dtype=float32),
#  array(0.00216329, dtype=float32),
#  array(0.00217851, dtype=float32),
#  array(0.00237472, dtype=float32),
#  array(0.00223582, dtype=float32),
#  array(0.00225818, dtype=float32),
#  array(0.00225853, dtype=float32),
#  array(0.00218432, dtype=float32),
#  array(0.00255025, dtype=float32),
#  array(0.00227494, dtype=float32),
#  array(0.00240614, dtype=float32),
#  array(0.00230341, dtype=float32),
#  array(0.00240264, dtype=float32),
#  array(0.00223638, dtype=float32),
#  array(0.00221717, dtype=float32),
#  array(0.00227224, dtype=float32),
#  array(0.00230679, dtype=float32),
#  array(0.00232132, dtype=float32),
#  array(0.00220418, dtype=float32),
#  array(0.00230464, dtype=float32),
#  array(0.00240559, dtype=float32),
#  array(0.00206249, dtype=float32),
#  array(0.0022899, dtype=float32),
#  array(0.00232624, dtype=float32),
#  array(0.00236944, dtype=float32),
#  array(0.00224643, dtype=float32),
#  array(0.00236695, dtype=float32),
#  array(0.00234102, dtype=float32),
#  array(0.00238372, dtype=float32),
#  array(0.00235035, dtype=float32),
#  array(0.00219034, dtype=float32),
#  array(0.00240575, dtype=float32),
#  array(0.00223286, dtype=float32),
#  array(0.00224058, dtype=float32),
#  array(0.00232558, dtype=float32),
#  array(0.00232019, dtype=float32),
#  array(0.00226008, dtype=float32),
#  array(0.00218124, dtype=float32),
#  array(0.00231412, dtype=float32),
#  array(0.0022551, dtype=float32),
#  array(0.00228236, dtype=float32),
#  array(0.0023073, dtype=float32),
#  array(0.00231811, dtype=float32),
#  array(0.00234262, dtype=float32),
#  array(0.00239907, dtype=float32),
#  array(0.00244143, dtype=float32),
#  array(0.00238462, dtype=float32),
#  array(0.00232412, dtype=float32),
#  array(0.00231211, dtype=float32),
#  array(0.00233567, dtype=float32),
#  array(0.00232219, dtype=float32),
#  array(0.00237309, dtype=float32),
#  array(0.00240229, dtype=float32),
#  array(0.00222627, dtype=float32),
#  array(0.00228687, dtype=float32),
#  array(0.00214118, dtype=float32),
#  array(0.00241042, dtype=float32),
#  array(0.00219519, dtype=float32),
#  array(0.00209971, dtype=float32),
#  array(0.00218161, dtype=float32),
#  array(0.00228508, dtype=float32),
#  array(0.00230561, dtype=float32),
#  array(0.00236605, dtype=float32),
#  array(0.00221739, dtype=float32),
#  array(0.00231795, dtype=float32),
#  array(0.00231356, dtype=float32),
#  array(0.00237297, dtype=float32),
#  array(0.00244841, dtype=float32),
#  array(0.00239547, dtype=float32),
#  array(0.00232856, dtype=float32),
#  array(0.00219043, dtype=float32),
#  array(0.00217297, dtype=float32),
#  array(0.00227867, dtype=float32),
#  array(0.00229786, dtype=float32),
#  array(0.00233966, dtype=float32),
#  array(0.00233276, dtype=float32),
#  array(0.00240062, dtype=float32),
#  array(0.00212887, dtype=float32),
#  array(0.00230212, dtype=float32),
#  array(0.00235668, dtype=float32),
#  array(0.00228808, dtype=float32),
#  array(0.00221639, dtype=float32),
#  array(0.00224209, dtype=float32),
#  array(0.00220005, dtype=float32),
#  array(0.0021899, dtype=float32),
#  array(0.00220537, dtype=float32),
#  array(0.00227515, dtype=float32),
#  array(0.00242164, dtype=float32),
#  array(0.00251546, dtype=float32),
#  array(0.0023636, dtype=float32),
#  array(0.00210847, dtype=float32),
#  array(0.00228458, dtype=float32),
#  array(0.00233424, dtype=float32),
#  array(0.00247072, dtype=float32),
#  array(0.00219105, dtype=float32),
#  array(0.00234714, dtype=float32),
#  array(0.00236909, dtype=float32),
#  array(0.0023606, dtype=float32),
#  array(0.00237906, dtype=float32),
#  array(0.0022818, dtype=float32),
#  array(0.00238447, dtype=float32),
#  array(0.00231371, dtype=float32),
#  array(0.00261108, dtype=float32),
#  array(0.00220338, dtype=float32),
#  array(0.00216679, dtype=float32),
#  array(0.0021956, dtype=float32),
#  array(0.00240669, dtype=float32),
#  array(0.00224382, dtype=float32),
#  array(0.00215713, dtype=float32),
#  array(0.00235529, dtype=float32),
#  array(0.00215809, dtype=float32),
#  array(0.00236309, dtype=float32),
#  array(0.00242766, dtype=float32),
#  array(0.00216739, dtype=float32),
#  array(0.00235723, dtype=float32),
#  array(0.00249846, dtype=float32),
#  array(0.00223534, dtype=float32),
#  array(0.00226051, dtype=float32),
#  array(0.00230089, dtype=float32),
#  array(0.00222856, dtype=float32),
#  array(0.0023667, dtype=float32),
#  array(0.00231283, dtype=float32),
#  array(0.00237293, dtype=float32),
#  array(0.00222154, dtype=float32),
#  array(0.00219446, dtype=float32),
#  array(0.00219838, dtype=float32),
#  array(0.00223339, dtype=float32),
#  array(0.00239199, dtype=float32),
#  array(0.00222914, dtype=float32),
#  array(0.0022463, dtype=float32),
#  array(0.0024565, dtype=float32),
#  array(0.00232642, dtype=float32),
#  array(0.00231032, dtype=float32),
#  array(0.00231483, dtype=float32),
#  array(0.00222576, dtype=float32),
#  array(0.00227733, dtype=float32),
#  array(0.0025434, dtype=float32),
#  array(0.00234665, dtype=float32),
#  array(0.00230599, dtype=float32),
#  array(0.00221087, dtype=float32),
#  array(0.00233162, dtype=float32),
#  array(0.00226584, dtype=float32),
#  array(0.00215547, dtype=float32),
#  array(0.00238933, dtype=float32),
#  array(0.00214986, dtype=float32),
#  array(0.00230548, dtype=float32),
#  array(0.00217198, dtype=float32),
#  array(0.00226896, dtype=float32),
#  array(0.00232458, dtype=float32),
#  array(0.00224026, dtype=float32),
#  array(0.00212051, dtype=float32),
#  array(0.00242226, dtype=float32),
#  array(0.00235268, dtype=float32),
#  array(0.00239001, dtype=float32),
#  array(0.00222107, dtype=float32),
#  array(0.00219561, dtype=float32),
#  array(0.00220158, dtype=float32),
#  array(0.00210787, dtype=float32),
#  array(0.00248406, dtype=float32),
#  array(0.00219177, dtype=float32),
#  array(0.00227002, dtype=float32),
#  array(0.00228561, dtype=float32),
#  array(0.00211861, dtype=float32),
#  array(0.00220759, dtype=float32),
#  array(0.0022103, dtype=float32),
#  array(0.00227275, dtype=float32),
#  array(0.00219247, dtype=float32),
#  array(0.00237188, dtype=float32),
#  array(0.00234936, dtype=float32),
#  array(0.00215581, dtype=float32),
#  array(0.00229436, dtype=float32),
#  array(0.00245098, dtype=float32),
#  array(0.00264399, dtype=float32),
#  array(0.00227107, dtype=float32),
#  array(0.00222018, dtype=float32),
#  array(0.00226174, dtype=float32),
#  array(0.00217602, dtype=float32),
#  array(0.00232427, dtype=float32),
#  array(0.00227172, dtype=float32),
#  array(0.00218147, dtype=float32),
#  array(0.00232797, dtype=float32),
#  array(0.00233958, dtype=float32),
#  array(0.00244726, dtype=float32),
#  array(0.00228295, dtype=float32),
#  array(0.00215418, dtype=float32),
#  array(0.0022584, dtype=float32),
#  array(0.00229906, dtype=float32),
#  array(0.00222365, dtype=float32),
#  array(0.0023765, dtype=float32),
#  array(0.00220954, dtype=float32),
#  array(0.00223566, dtype=float32),
#  array(0.00228694, dtype=float32),
#  array(0.00237909, dtype=float32),
#  array(0.0024763, dtype=float32),
#  array(0.00241616, dtype=float32),
#  array(0.00245623, dtype=float32),
#  array(0.0021967, dtype=float32),
#  array(0.00219676, dtype=float32),
#  array(0.0022213, dtype=float32),
#  array(0.0022055, dtype=float32),
#  array(0.00236844, dtype=float32),
#  array(0.00227671, dtype=float32),
#  array(0.0023219, dtype=float32),
#  array(0.00242917, dtype=float32),
#  array(0.00232868, dtype=float32),
#  array(0.00229256, dtype=float32),
#  array(0.00223814, dtype=float32),
#  array(0.00233822, dtype=float32),
#  array(0.00226119, dtype=float32),
#  array(0.00241082, dtype=float32),
#  array(0.0022788, dtype=float32),
#  array(0.00219303, dtype=float32),
#  array(0.00230561, dtype=float32),
#  array(0.00216979, dtype=float32),
#  array(0.00238263, dtype=float32),
#  array(0.00213604, dtype=float32),
#  array(0.00222595, dtype=float32),
#  array(0.00240021, dtype=float32),
#  array(0.00228275, dtype=float32),
#  array(0.00229017, dtype=float32),
#  array(0.00246332, dtype=float32),
#  array(0.00215158, dtype=float32),
#  array(0.00240834, dtype=float32),
#  array(0.00243003, dtype=float32),
#  array(0.00206979, dtype=float32),
#  array(0.00242196, dtype=float32),
#  array(0.00240685, dtype=float32),
#  array(0.00222377, dtype=float32),
#  array(0.00220372, dtype=float32),
#  array(0.00225547, dtype=float32),
#  array(0.00211472, dtype=float32),
#  array(0.00228722, dtype=float32),
#  array(0.00219787, dtype=float32),
#  array(0.00232954, dtype=float32),
#  array(0.00219931, dtype=float32),
#  array(0.00225249, dtype=float32),
#  array(0.00226556, dtype=float32),
#  array(0.00227979, dtype=float32),
#  array(0.00244797, dtype=float32),
#  array(0.00231857, dtype=float32),
#  array(0.00237332, dtype=float32),
#  array(0.00236558, dtype=float32),
#  array(0.00241063, dtype=float32),
#  array(0.00239213, dtype=float32),
#  array(0.00226274, dtype=float32),
#  array(0.00236175, dtype=float32),
#  array(0.00232947, dtype=float32),
#  array(0.00227312, dtype=float32),
#  array(0.00219515, dtype=float32),
#  array(0.00228929, dtype=float32),
#  array(0.00219266, dtype=float32),
#  array(0.00217364, dtype=float32),
#  array(0.00237022, dtype=float32),
#  array(0.00236739, dtype=float32),
#  array(0.00236001, dtype=float32),
#  array(0.00236288, dtype=float32),
#  array(0.00215214, dtype=float32),
#  array(0.0025272, dtype=float32),
#  array(0.00235143, dtype=float32),
#  array(0.00252699, dtype=float32),
#  array(0.00227295, dtype=float32),
#  array(0.00227803, dtype=float32),
#  array(0.00220293, dtype=float32),
#  array(0.00248868, dtype=float32),
#  array(0.00217165, dtype=float32),
#  array(0.00243204, dtype=float32),
#  array(0.00252242, dtype=float32),
#  array(0.00234124, dtype=float32),
#  array(0.00210468, dtype=float32),
#  array(0.00225767, dtype=float32),
#  array(0.00228193, dtype=float32),
#  array(0.00223295, dtype=float32),
#  array(0.0021687, dtype=float32),
#  array(0.0021751, dtype=float32),
#  array(0.00210266, dtype=float32),
#  array(0.00222463, dtype=float32),
#  array(0.00227178, dtype=float32),
#  array(0.0023926, dtype=float32),
#  array(0.00231197, dtype=float32),
#  array(0.00218907, dtype=float32),
#  array(0.0024377, dtype=float32),
#  array(0.00221125, dtype=float32),
#  array(0.00228774, dtype=float32),
#  array(0.00222945, dtype=float32),
#  array(0.00216136, dtype=float32),
#  array(0.00245136, dtype=float32),
#  array(0.00223574, dtype=float32),
#  array(0.002357, dtype=float32),
#  array(0.00228488, dtype=float32),
#  array(0.00232907, dtype=float32),
#  array(0.00224657, dtype=float32),
#  array(0.00231683, dtype=float32),
#  array(0.00216788, dtype=float32),
#  array(0.00223543, dtype=float32),
#  array(0.00221592, dtype=float32),
#  array(0.00248555, dtype=float32),
#  array(0.00235361, dtype=float32),
#  array(0.00250987, dtype=float32),
#  array(0.00233792, dtype=float32),
#  array(0.00224199, dtype=float32),
#  array(0.00233816, dtype=float32),
#  array(0.00230699, dtype=float32),
#  array(0.00222698, dtype=float32),
#  array(0.00240863, dtype=float32),
#  array(0.00236327, dtype=float32),
#  array(0.00221047, dtype=float32),
#  array(0.00221353, dtype=float32),
#  array(0.00210927, dtype=float32),
#  array(0.00222085, dtype=float32),
#  array(0.00236078, dtype=float32),
#  array(0.00243303, dtype=float32),
#  array(0.0022007, dtype=float32),
#  array(0.00227204, dtype=float32),
#  array(0.00237759, dtype=float32),
#  array(0.0022535, dtype=float32),
#  array(0.00220127, dtype=float32),
#  array(0.002429, dtype=float32),
#  array(0.00233526, dtype=float32),
#  array(0.0022921, dtype=float32),
#  array(0.00228412, dtype=float32),
#  array(0.00239774, dtype=float32),
#  array(0.00231415, dtype=float32),
#  array(0.00239759, dtype=float32),
#  array(0.00222823, dtype=float32),
#  array(0.00249388, dtype=float32),
#  array(0.00229003, dtype=float32),
#  array(0.00225314, dtype=float32),
#  array(0.00242043, dtype=float32),
#  array(0.00224428, dtype=float32),
#  array(0.00239873, dtype=float32),
#  array(0.00235648, dtype=float32),
#  array(0.00232232, dtype=float32),
#  array(0.00240147, dtype=float32),
#  array(0.00214212, dtype=float32),
#  array(0.00213217, dtype=float32),
#  array(0.0021109, dtype=float32),
#  array(0.00236794, dtype=float32),
#  array(0.00214161, dtype=float32),
#  array(0.0025019, dtype=float32),
#  array(0.00233806, dtype=float32),
#  array(0.00228011, dtype=float32),
#  array(0.00236098, dtype=float32),
#  array(0.00203546, dtype=float32),
#  array(0.00238295, dtype=float32),
#  array(0.00229688, dtype=float32),
#  array(0.00221014, dtype=float32),
#  array(0.00214788, dtype=float32),
#  array(0.002223, dtype=float32),
#  array(0.00228726, dtype=float32),
#  array(0.00243329, dtype=float32),
#  array(0.00226996, dtype=float32),
#  array(0.00216849, dtype=float32),
#  array(0.00224247, dtype=float32),
#  array(0.00240838, dtype=float32),
#  array(0.00232013, dtype=float32),
#  array(0.00227558, dtype=float32),
#  array(0.00228348, dtype=float32),
#  array(0.00236583, dtype=float32),
#  array(0.00218301, dtype=float32),
#  array(0.00238205, dtype=float32),
#  array(0.0022201, dtype=float32),
#  array(0.00238533, dtype=float32),
#  array(0.00216602, dtype=float32),
#  array(0.00226137, dtype=float32),
#  array(0.00218797, dtype=float32),
#  array(0.00241316, dtype=float32),
#  array(0.00227141, dtype=float32),
#  array(0.00226907, dtype=float32),
#  array(0.00236434, dtype=float32),
#  array(0.00251157, dtype=float32),
#  array(0.00246245, dtype=float32),
#  array(0.00223086, dtype=float32),
#  array(0.00224249, dtype=float32),
#  array(0.00229447, dtype=float32),
#  array(0.00221342, dtype=float32),
#  array(0.0021127, dtype=float32),
#  array(0.00219879, dtype=float32),
#  array(0.00226308, dtype=float32),
#  array(0.00224681, dtype=float32),
#  array(0.00214488, dtype=float32),
#  array(0.00234446, dtype=float32),
#  array(0.00242849, dtype=float32),
#  array(0.00234565, dtype=float32),
#  array(0.00232309, dtype=float32),
#  array(0.00223605, dtype=float32),
#  array(0.00228191, dtype=float32),
#  array(0.0024244, dtype=float32),
#  array(0.00249325, dtype=float32),
#  array(0.0024975, dtype=float32),
#  array(0.00256258, dtype=float32),
#  array(0.00225304, dtype=float32),
#  array(0.00220888, dtype=float32),
#  array(0.00229605, dtype=float32),
#  array(0.00236288, dtype=float32),
#  array(0.00236416, dtype=float32),
#  array(0.00212337, dtype=float32),
#  array(0.00244042, dtype=float32),
#  array(0.00225811, dtype=float32),
#  array(0.00211631, dtype=float32),
#  array(0.00232992, dtype=float32),
#  array(0.00222309, dtype=float32),
#  array(0.00225232, dtype=float32),
#  array(0.00245729, dtype=float32),
#  array(0.002222, dtype=float32),
#  array(0.00221786, dtype=float32),
#  array(0.00223554, dtype=float32),
#  array(0.00211534, dtype=float32),
#  array(0.00224827, dtype=float32),
#  array(0.00231427, dtype=float32),
#  array(0.00226379, dtype=float32),
#  array(0.0025344, dtype=float32),
#  array(0.0022495, dtype=float32),
#  array(0.002318, dtype=float32),
#  array(0.00217948, dtype=float32),
#  array(0.00235809, dtype=float32),
#  array(0.00239788, dtype=float32),
#  array(0.00225878, dtype=float32),
#  array(0.00216951, dtype=float32),
#  array(0.00236586, dtype=float32),
#  array(0.00214844, dtype=float32),
#  array(0.00236358, dtype=float32),
#  array(0.00221393, dtype=float32),
#  array(0.00228582, dtype=float32),
#  array(0.00230409, dtype=float32),
#  array(0.00243453, dtype=float32),
#  array(0.00226434, dtype=float32),
#  array(0.00238928, dtype=float32),
#  array(0.00219478, dtype=float32),
#  array(0.00223997, dtype=float32),
#  array(0.00237996, dtype=float32),
#  array(0.00234552, dtype=float32),
#  array(0.00233756, dtype=float32),
#  array(0.00218491, dtype=float32),
#  array(0.00226205, dtype=float32),
#  array(0.00226569, dtype=float32),
#  array(0.00229569, dtype=float32),
#  array(0.00220816, dtype=float32),
#  array(0.00219406, dtype=float32),
#  array(0.00235832, dtype=float32),
#  array(0.00224714, dtype=float32),
#  array(0.00219197, dtype=float32),
#  array(0.00227102, dtype=float32),
#  array(0.00226793, dtype=float32),
#  array(0.00224544, dtype=float32),
#  array(0.00217899, dtype=float32),
#  array(0.00226966, dtype=float32),
#  array(0.00224376, dtype=float32),
#  array(0.00224608, dtype=float32),
#  array(0.00223861, dtype=float32),
#  array(0.00226925, dtype=float32),
#  array(0.00224248, dtype=float32),
#  array(0.00225996, dtype=float32),
#  array(0.00224472, dtype=float32),
#  array(0.00227966, dtype=float32),
#  array(0.00234807, dtype=float32),
#  array(0.00225685, dtype=float32),
#  array(0.00219567, dtype=float32),
#  array(0.00226402, dtype=float32),
#  array(0.00222188, dtype=float32),
#  array(0.00245777, dtype=float32),
#  array(0.00231255, dtype=float32),
#  array(0.00236909, dtype=float32),
#  array(0.00248523, dtype=float32),
#  array(0.00217311, dtype=float32),
#  array(0.00234411, dtype=float32),
#  array(0.00218158, dtype=float32),
#  array(0.00219928, dtype=float32),
#  array(0.00219751, dtype=float32),
#  array(0.00241515, dtype=float32),
#  array(0.00243466, dtype=float32),
#  array(0.00229783, dtype=float32),
#  array(0.00219096, dtype=float32),
#  array(0.00245377, dtype=float32),
#  array(0.00235466, dtype=float32),
#  array(0.00223127, dtype=float32),
#  array(0.00246271, dtype=float32),
#  array(0.00229162, dtype=float32),
#  array(0.00229119, dtype=float32),
#  array(0.00226611, dtype=float32),
#  array(0.00233014, dtype=float32),
#  array(0.00218522, dtype=float32),
#  array(0.0023502, dtype=float32),
#  array(0.00225286, dtype=float32),
#  array(0.00238077, dtype=float32),
#  array(0.00212276, dtype=float32),
#  array(0.00224941, dtype=float32),
#  array(0.00250927, dtype=float32),
#  array(0.00248568, dtype=float32),
#  array(0.00230931, dtype=float32),
#  array(0.00223628, dtype=float32),
#  array(0.00236732, dtype=float32),
#  array(0.00230414, dtype=float32),
#  array(0.00216885, dtype=float32),
#  array(0.0022669, dtype=float32),
#  array(0.00223279, dtype=float32),
#  array(0.00233107, dtype=float32),
#  array(0.00239673, dtype=float32),
#  array(0.00231572, dtype=float32),
#  array(0.00227512, dtype=float32),
#  array(0.00228054, dtype=float32),
#  array(0.00233299, dtype=float32),
#  array(0.00232467, dtype=float32),
#  array(0.00225774, dtype=float32),
#  array(0.00258136, dtype=float32),
#  array(0.00231533, dtype=float32),
#  array(0.00223877, dtype=float32),
#  array(0.00228668, dtype=float32),
#  array(0.00228462, dtype=float32),
#  array(0.00237392, dtype=float32),
#  array(0.00230762, dtype=float32),
#  array(0.0022535, dtype=float32),
#  array(0.00235921, dtype=float32),
#  array(0.00233318, dtype=float32),
#  array(0.00213283, dtype=float32),
#  array(0.00223663, dtype=float32),
#  array(0.00234323, dtype=float32),
#  array(0.00224056, dtype=float32),
#  array(0.00224843, dtype=float32),
#  array(0.00248516, dtype=float32),
#  array(0.00227782, dtype=float32),
#  array(0.00228225, dtype=float32),
#  array(0.00242809, dtype=float32),
#  array(0.00214498, dtype=float32),
#  array(0.0022192, dtype=float32),
#  array(0.00235942, dtype=float32),
#  array(0.00229309, dtype=float32),
#  array(0.00223363, dtype=float32),
#  array(0.00233884, dtype=float32),
#  array(0.00224919, dtype=float32),
#  array(0.00228774, dtype=float32),
#  array(0.00224732, dtype=float32),
#  array(0.00242731, dtype=float32),
#  array(0.00221941, dtype=float32),
#  array(0.00236324, dtype=float32),
#  array(0.0022862, dtype=float32),
#  array(0.00232154, dtype=float32),
#  array(0.00235337, dtype=float32),
#  array(0.00220804, dtype=float32),
#  array(0.00237974, dtype=float32),
#  array(0.00215667, dtype=float32),
#  array(0.0022907, dtype=float32),
#  array(0.00245593, dtype=float32),
#  array(0.00236136, dtype=float32),
#  array(0.00234109, dtype=float32),
#  array(0.00235158, dtype=float32),
#  array(0.00223881, dtype=float32),
#  array(0.00224072, dtype=float32),
#  array(0.00226765, dtype=float32),
#  array(0.0023508, dtype=float32),
#  array(0.00231299, dtype=float32),
#  array(0.00234225, dtype=float32),
#  array(0.00232201, dtype=float32),
#  array(0.00238219, dtype=float32),
#  array(0.00241916, dtype=float32),
#  array(0.00229154, dtype=float32),
#  array(0.00255993, dtype=float32),
#  array(0.00225915, dtype=float32),
#  array(0.00225649, dtype=float32),
#  array(0.00226863, dtype=float32),
#  array(0.0023052, dtype=float32),
#  array(0.00234169, dtype=float32),
#  array(0.00222697, dtype=float32),
#  array(0.00208451, dtype=float32),
#  array(0.00233665, dtype=float32),
#  array(0.00226696, dtype=float32),
#  array(0.00229872, dtype=float32),
#  array(0.00234195, dtype=float32),
#  array(0.00225787, dtype=float32),
#  array(0.0023345, dtype=float32),
#  array(0.00230881, dtype=float32),
#  array(0.00220685, dtype=float32),
#  array(0.00214242, dtype=float32),
#  array(0.00237468, dtype=float32),
#  array(0.00241405, dtype=float32),
#  array(0.00234835, dtype=float32),
#  array(0.00234457, dtype=float32),
#  array(0.00234963, dtype=float32),
#  array(0.00216668, dtype=float32),
#  ...]

# %%
trainer.evaluate(graph_test)
#trainer.evaluate(dev_graph_train)
# Out:
# 2.88085686718791e-07

# %%
class ANITrainer:
    def __init__(self, model, batch_size, epoch, opt_method="adam", loss_func=nn.MSELoss(), learning_rate=1e-3, l2=1e-9):
        self.model = model
        
        num_params = sum(item.numel() for item in model.parameters())
        print(f"{model.__class__.__name__} - Number of parameters: {num_params}")

        if opt_method == "sgdm":
            self.optimizer = torch.optim.SGD(model.parameters(), learning_rate, momentum=0.9)
        elif opt_method == "adam":
            self.optimizer = torch.optim.Adam(model.parameters(), learning_rate, weight_decay=l2)
        else:
            raise NotImplementedError("This optimization is not supported")
        self.epoch = epoch
        self.batch_size = batch_size
        #Generally MSE is better than cross-entropy for regression, so it is the default
        
        self.loss = loss_func
        self.batch_size = batch_size
        self.epoch = epoch
    
    def train(self, train_data, val_data, early_stop=True, draw_curve=True):
        self.model.train()
        
        # init data loader
        print("Initialize training data...")
        train_data_loader = train_data.collate(batch_size).cache()
        #val_data_loader = val_data.collate(batch_size).cache()
        
        # definition of loss function: MSE is a good choice! 
        loss_func = self.loss
        
        # record epoch losses
        train_loss_list, val_loss_list, lowest_val_loss = [], [], np.inf

        
        for i in tqdm(range(self.epoch), leave=True):
            train_epoch_loss = 0.0
            for train_data_batch in train_data_loader:
                #print("computing energies...")
                # compute energies
                species = train_data_batch['species'].to(device)
                coords = train_data_batch['coordinates'].to(device)
                true_energies = train_data_batch['energies'].to(device).float()
                _, pred_energies = model((species, coords))
                
                # compute loss
                batch_loss = loss_func(true_energies, pred_energies)
                
                # do a step
                self.optimizer.zero_grad()
                batch_loss.backward()
                self.optimizer.step()
                
                batch_importance = pred_energies.shape[0]/len(train_data)
                train_epoch_loss += batch_loss.detach().to(device).item() * batch_importance
            
            # use the self.evaluate to get loss on the validation set 
            val_epoch_loss = self.evaluate(val_data, draw_plot=False)
            
            # append the losses
            train_loss_list.append(train_epoch_loss)
            val_loss_list.append(val_epoch_loss)

            if early_stop:
                if val_epoch_loss < lowest_val_loss:
                    lowest_val_loss = val_epoch_loss
                    weights = self.model.state_dict()
        
        if draw_curve:
            fig, ax = plt.subplots(1, 1, figsize=(5, 4), constrained_layout=True)
            ax.set_yscale("log")
            x_axis = np.arange(self.epoch)
            # Plot train loss and validation loss
            ax.plot(x_axis, train_loss_list, label='Train')
            ax.plot(x_axis, val_loss_list, label='Validation')
            ax.legend()
            ax.set_xlabel("# Batch")
            ax.set_ylabel("Loss")
        
        if early_stop:
            self.model.load_state_dict(weights)
        
        return train_loss_list, val_loss_list
    
    
    def evaluate(self, data, draw_plot=False):
        self.model.eval()
        #print("evaluate has been called")
        # init data loader
        data_loader = data.collate(batch_size).cache()
        
        # init loss function
        loss_func = self.loss
        total_loss = 0.0
        
        if draw_plot:
            true_energies_all = []
            pred_energies_all = []
            
        with torch.no_grad():
            for batch_data in data_loader:
                
                # compute energies
                species = batch_data['species'].to(device)
                coords = batch_data['coordinates'].to(device)
                true_energies = batch_data['energies'].to(device).float()
                _, pred_energies = model((species, coords))
                
                # compute loss
                batch_loss = loss_func(pred_energies, true_energies)

                batch_importance = pred_energies.shape[0] / len(data)
                total_loss += batch_loss.detach().to(device).item() * batch_importance
                
                if draw_plot:
                    true_energies_all.append(true_energies.detach().cpu().numpy().flatten())
                    pred_energies_all.append(pred_energies.detach().cpu().numpy().flatten())

        if draw_plot:
            true_energies_all = np.concatenate(true_energies_all)
            pred_energies_all = np.concatenate(pred_energies_all)
            # Report the mean absolute error
            # The unit of energies in the dataset is hartree
            # please convert it to kcal/mol when reporting the mean absolute error
            # 1 hartree = 627.5094738898777 kcal/mol
            # MAE = mean(|true - pred|)
            hartree2kcalmol = 627.5094738898777
            mae = np.mean(np.abs(true_energies_all - pred_energies_all)) * hartree2kcalmol
            fig, ax = plt.subplots(1, 1, figsize=(5, 4), constrained_layout=True)
            ax.scatter(true_energies_all, pred_energies_all, label=f"MAE: {mae:.2f} kcal/mol", s=2)
            ax.set_xlabel("Ground Truth")
            ax.set_ylabel("Predicted")
            xmin, xmax = ax.get_xlim()
            ymin, ymax = ax.get_ylim()
            vmin, vmax = min(xmin, ymin), max(xmax, ymax)
            ax.set_xlim(vmin, vmax)
            ax.set_ylim(vmin, vmax)
            ax.plot([vmin, vmax], [vmin, vmax], color='red')
            ax.legend()
            
        return total_loss

# %%
class AtomicNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(384, 128),
            nn.ReLU(),
            nn.Linear(128, 1)
        )
    
    def forward(self, x):
        return self.layers(x)

net_H = AtomicNet()
net_C = AtomicNet()
net_N = AtomicNet()
net_O = AtomicNet()

# ANI model requires a network for each atom type
# use torch.ANIModel() to compile atomic networks
ani_net = torchani.ANIModel([net_H, net_C, net_N, net_O])
model = nn.Sequential(
    aev_computer,
    ani_net
).to(device)

# %%
class wideAtomicNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(384, 1024),
            nn.ReLU(),
            nn.Linear(1024, 1)
        )
    
    def forward(self, x):
        return self.layers(x)

net_H = wideAtomicNet()
net_C = wideAtomicNet()
net_N = wideAtomicNet()
net_O = wideAtomicNet()

# ANI model requires a network for each atom type
# use torch.ANIModel() to compile atomic networks
wide_ani_net = torchani.ANIModel([net_H, net_C, net_N, net_O])
model = nn.Sequential(
    aev_computer,
    wide_ani_net
).to(device)

# %%
class deepAtomicNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(384, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128,128),
            nn.ReLU(),
            nn.Linear(128, 1)
        )
    
    def forward(self, x):
        return self.layers(x)

net_H = deepAtomicNet()
net_C = deepAtomicNet()
net_N = deepAtomicNet()
net_O = deepAtomicNet()

# ANI model requires a network for each atom type
# use torch.ANIModel() to compile atomic networks
deep_ani_net = torchani.ANIModel([net_H, net_C, net_N, net_O])
model = nn.Sequential(
    aev_computer,
    deep_ani_net
).to(device)

# %%
class bigAtomicNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(384, 1024),
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 1)
        )
    def forward(self, x):
        return self.layers(x)

net_H = bigAtomicNet()
net_C = bigAtomicNet()
net_N = bigAtomicNet()
net_O = bigAtomicNet()

# ANI model requires a network for each atom type
# use torch.ANIModel() to compile atomic networks
big_ani_net = torchani.ANIModel([net_H, net_C, net_N, net_O])
model = nn.Sequential(
    aev_computer,
    big_ani_net
).to(device)

# %% [markdown]
# I decided not to use the "bigAtomicNet" class: it performed much better on my small debugging datasets, but was too computationally expensive to use here.  "deepAtomicNet" already has great performance.

# %%
# Instantiate the ANITrainer with the model, batch_size, epoch, and other necessary parameters
epoch = 100
batch_size = 2048
trainer = ANITrainer(model=model, batch_size=batch_size, epoch=epoch, opt_method="adam", loss_func=nn.MSELoss(), learning_rate=1e-3, l2=1e-9)
# Out:
# Sequential - Number of parameters: 329732

# %%
# Train the model using the train_data_loader and val_data_loader
train_loss_list, val_loss_list = trainer.train(train_data, val_data, early_stop=True, draw_curve=True)
trainer.evaluate(test_data, draw_plot=True)
# Out:
# Initialize training data...
# 100%|██████████| 100/100 [20:15<00:00, 12.15s/it]
# 1.0547970598648817e-06

# %%
trainer.evaluate(test_data, draw_plot=True)
# Out:
# 2.8398482470838087e-05
